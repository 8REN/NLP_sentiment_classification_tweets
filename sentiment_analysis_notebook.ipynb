# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#functions" data-toc-modified-id="functions-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>functions</a></span></li></ul></li><li><span><a href="#Obtain-data" data-toc-modified-id="Obtain-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Obtain data</a></span></li><li><span><a href="#Scrub-data" data-toc-modified-id="Scrub-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Scrub data</a></span><ul class="toc-item"><li><span><a href="#missing-data" data-toc-modified-id="missing-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>missing data</a></span><ul class="toc-item"><li><span><a href="#missing-tweet-data" data-toc-modified-id="missing-tweet-data-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>missing tweet data</a></span></li><li><span><a href="#missing-product-data" data-toc-modified-id="missing-product-data-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>missing product data</a></span></li></ul></li><li><span><a href="#remove-twitter-handles-from-tweet-text" data-toc-modified-id="remove-twitter-handles-from-tweet-text-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>remove twitter handles from tweet text</a></span></li><li><span><a href="#clean-tweet-text" data-toc-modified-id="clean-tweet-text-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>clean tweet text</a></span></li></ul></li><li><span><a href="#sentiment-column-clean-up" data-toc-modified-id="sentiment-column-clean-up-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>sentiment column clean up</a></span></li><li><span><a href="#Explore" data-toc-modified-id="Explore-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Explore</a></span></li><li><span><a href="#More-Scrubbing" data-toc-modified-id="More-Scrubbing-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>More Scrubbing</a></span><ul class="toc-item"><li><span><a href="#stopwords-assessment-and-removal" data-toc-modified-id="stopwords-assessment-and-removal-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>stopwords assessment and removal</a></span></li><li><span><a href="#tokenize,-lemmatize,-stemming" data-toc-modified-id="tokenize,-lemmatize,-stemming-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>tokenize, lemmatize, stemming</a></span></li></ul></li><li><span><a href="#further-exploration-of-only-positive-and-negative-sentiment" data-toc-modified-id="further-exploration-of-only-positive-and-negative-sentiment-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>further exploration of only positive and negative sentiment</a></span><ul class="toc-item"><li><span><a href="#of-only-positive-and-negative-sentiment" data-toc-modified-id="of-only-positive-and-negative-sentiment-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>of only positive and negative sentiment</a></span></li><li><span><a href="#assess-word-frequency" data-toc-modified-id="assess-word-frequency-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>assess word frequency</a></span></li></ul></li><li><span><a href="#model" data-toc-modified-id="model-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>model</a></span><ul class="toc-item"><li><span><a href="#functions" data-toc-modified-id="functions-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>functions</a></span></li><li><span><a href="#PCA-data-visualization" data-toc-modified-id="PCA-data-visualization-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>PCA data visualization</a></span></li><li><span><a href="#transform-data-from-strings-to-numeric-data" data-toc-modified-id="transform-data-from-strings-to-numeric-data-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>transform data from strings to numeric data</a></span></li><li><span><a href="#prepare-data-for-model" data-toc-modified-id="prepare-data-for-model-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>prepare data for model</a></span></li></ul></li><li><span><a href="#nn-model1" data-toc-modified-id="nn-model1-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>nn model1</a></span><ul class="toc-item"><li><span><a href="#nn_model-#2" data-toc-modified-id="nn_model-#2-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>nn_model #2</a></span></li><li><span><a href="#nn-model-3" data-toc-modified-id="nn-model-3-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>nn model 3</a></span></li></ul></li><li><span><a href="#nn-model-no-SMOTE,-use-weights" data-toc-modified-id="nn-model-no-SMOTE,-use-weights-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>nn model no SMOTE, use weights</a></span><ul class="toc-item"><li><span><a href="#model-and-assess-using-statistical-methods" data-toc-modified-id="model-and-assess-using-statistical-methods-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>model and assess using statistical methods</a></span></li></ul></li><li><span><a href="#use-best-performing-model-on-this-data" data-toc-modified-id="use-best-performing-model-on-this-data-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>use best performing model on this data</a></span></li><li><span><a href="#word2vec" data-toc-modified-id="word2vec-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>word2vec</a></span></li><li><span><a href="#Final-Model" data-toc-modified-id="Final-Model-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Final Model</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %%
#import modules for Obtain/Scrub/Explore
import re
import pandas as pd 
import numpy as np 
import nltk
import string
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
import warnings 
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#import modules for tokenizing and stemming 
from nltk.collocations import *
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
from nltk import pos_tag
from collections import defaultdict
from nltk.stem import WordNetLemmatizer 
from collections import Counter
from nltk.tokenize.treebank import TreebankWordTokenizer, TreebankWordDetokenizer
from nltk.probability import FreqDist

# %% [markdown]
# ## functions

# %%
# function using contraction dictionary to replace/expand contractions
cList = {
  "ain't": "aint",
  "aren't": "are not",
  "can't": "can not",
  "can't've": "can not have",
  "'cause": "because",
  "bc": "because",
  "b/c": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text)

# %%
# function to clean up characters and unwanted items from tweet text
def scrub_tweet(df):
    for x in df:
        # expand contractions
        df = df.apply(expandContractions)
        # remove hash from tweet column, keeping word following hashtag
        df = df.str.replace(r"#", " ")
        # remove hyperlinks and {link}
        df = df.str.replace(r"(?:\@|http?\://|https?\://|www)\S+", " ")
        df = df.str.replace(r'{link}', " ")
        # remove random characters and punctuation
        df = df.str.replace(r'[^a-zA-Z]', " ")
        #remove digits
        df = df.str.replace(r'\d', " ")
        # deal with apostrophes
        df = df.str.replace(r'(\')', "")
        # remove individual/single chars
        df = df.str.replace(r'\b[a-z]\b', "")
        # remove double spaces
        df = df.str.replace(r'  ', " ")
        return df

# %%
stopwords_list = (stopwords.words('english')) 
add_stopwords = ('apple', 'ipad', 'iphone', 'android', 'ipadiphone', 'google', 'rt', 
                 'sxsw', 'sxswi', 'g', 'c', 'b', 'w', 't', 'austin', 'NaN')
stopwords_list.extend(add_stopwords)

stopwords_list.remove('not')

# %%
# function to remove stopwords from tweet pre-tokenize
def remove_stop_text(df):
    temp= df.apply(lambda x: ' '.join([word for word in x.split() 
                                                if word not in (stopwords_list)]))
    return temp

# %%
# function to remove stopwords from tweet post-tokenize
def stop_rem(words):
    tokens = [
    w for w in words 
        if w not in stopwords_list
    ]

# %%
# apply defined tokenizer to text
def toke_text(words):
    tokens = tokenizer.tokenize(words)
    return tokens

# %%
# apply defined lemmatizer to tokens
def lem_text(tokens):
    new_df = [lemmatizer.lemmatize(x) for x in tokens]
    return new_df

# %%
# apply defined stemmer to tokens
def stem_text(tokens):
    new_df = [stemmer.stem(x) for x in tokens]
    return new_df

# %%
# word frequency top 50
def top_50(df):
    temp = df.to_list()
    temp2 = [i for j in temp for i in j]
    temp_freqdist = FreqDist(temp2)
    print('50 MOST common words:', (temp_freqdist.most_common(50)))
    print('Total:', (len(temp_freqdist)))
    return (len(temp_freqdist))

# %% [markdown]
# # Obtain data

# %%
data = pd.read_csv('data/data.csv', sep=',')

# %%
data.tweet_text.iloc[4]
# Out:
# "@sxtxstate great stuff on Fri #SXSW: Marissa Mayer (Google), Tim O'Reilly (tech books/conferences) &amp; Matt Mullenweg (Wordpress)"

# %%
data.head()
# Out:
#                                           tweet_text  \
# 0  .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1  @jessedee Know about @fludapp ? Awesome iPad/i...
# 2  @swonderlin Can not wait for #iPad 2 also. The...
# 3  @sxsw I hope this year's festival isn't as cra...
# 4  @sxtxstate great stuff on Fri #SXSW: Marissa M...
#
#   emotion_in_tweet_is_directed_at  \
# 0                          iPhone
# 1              iPad or iPhone App
# 2                            iPad
# 3              iPad or iPhone App
# 4                          Google
#
#   is_there_an_emotion_directed_at_a_brand_or_product
# 0                                   Negative emotion
# 1                                   Positive emotion
# 2                                   Positive emotion
# 3                                   Negative emotion
# 4                                   Positive emotion

# %%
data.columns
# Out:
# Index(['tweet_text', 'emotion_in_tweet_is_directed_at',
#        'is_there_an_emotion_directed_at_a_brand_or_product'],
#       dtype='object')

# %%
data.dtypes
# Out:
# tweet_text                                            object
# emotion_in_tweet_is_directed_at                       object
# is_there_an_emotion_directed_at_a_brand_or_product    object
# dtype: object

# %%
data.shape
# Out:
# (8721, 3)

# %%
data = data.rename(columns={'tweet_text': 'tweet', 'emotion_in_tweet_is_directed_at': "product", 'is_there_an_emotion_directed_at_a_brand_or_product': 'sentiment'})

# %%
data.drop_duplicates(subset='tweet', keep='first', inplace=True)

# %% [markdown]
# # Scrub data

# %% [markdown]
# ##  missing data

# %% [markdown]
# ### missing tweet data

# %%
data['tweet'].isna().sum()
# Out:
# 1

# %%
data.isna().sum()
# Out:
# tweet           1
# product      5536
# sentiment       0
# dtype: int64

# %%
data.dropna(subset=['tweet'], axis=0, inplace=True)

# %%
data.shape
# Out:
# (8693, 3)

# %%
data['tweet'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### missing product data

# %%
# make tweet text lowercase for continuity
data['product'] = data['product'].str.lower()

# %%
data['product'].isna().sum()
# Out:
# 5535

# %%
# make tweet text lowercase for continuity
data['tweet'] = data['tweet'].str.lower()

# %%
# fill product column using keywords from tweet text
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('ipad')), 'product'] = 'ipad'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('iphone')), 'product'] = 'iphone'                                     
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('apple')), 'product'] = 'apple'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('android')), 'product'] = 'android'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('google')), 'product'] = 'google'
data.loc[(data['product'].isnull()) & (data['tweet'].str.contains('itunes')), 'product'] = 'apple app'

# %%
data['product'].unique()
# Out:
# array(['iphone', 'ipad or iphone app', 'ipad', 'google', 'android',
#        'apple', 'android app', 'other google product or service', nan,
#        'apple app', 'other apple product or service'], dtype=object)

# %%
data.dropna(subset=['product'], axis=0, inplace=True)

# %%
data.shape
# Out:
# (8014, 3)

# %%
data['product'].unique()
# Out:
# array(['iphone', 'ipad or iphone app', 'ipad', 'google', 'android',
#        'apple', 'android app', 'other google product or service',
#        'apple app', 'other apple product or service'], dtype=object)

# %%
# update values in product column
data['product'] = data['product'].replace(['other apple product or service'], 'apple other')
data['product'] = data['product'].replace(['ipad or iphone app'], 'apple app')
data['product'] = data['product'].replace(['ipad'], 'apple ipad')
data['product'] = data['product'].replace(['iphone'], 'apple iphone')
data['product'] = data['product'].replace(['android app'], 'android app')
data['product'] = data['product'].replace(['android'], 'android')
data['product'] = data['product'].replace(['google'], 'google')
data['product'] = data['product'].replace(['other google product or service'], 'google other')
data['product'] = data['product'].replace(['apple'], 'apple')

# %% [markdown]
# ## remove twitter handles from tweet text

# %%
#remove @mentions
data['tweet'] = data.apply(lambda row: 
    nltk.tokenize.casual.remove_handles(row['tweet']), axis=1)

# %%
from bs4 import BeautifulSoup
#HTML decoding
data['tweet'] = data.apply(lambda row: BeautifulSoup(row['tweet']).get_text().replace('\n',' '),axis=1)

# %%
data.head()
# Out:
#                                                tweet       product  \
# 0  .  i have a 3g iphone. after 3 hrs tweeting at...  apple iphone
# 1  know about   ? awesome ipad/iphone app that yo...     apple app
# 2  can not wait for #ipad 2 also. they should sal...    apple ipad
# 3  i hope this year's festival isn't as crashy as...     apple app
# 4  great stuff on fri #sxsw: marissa mayer (googl...        google
#
#           sentiment
# 0  Negative emotion
# 1  Positive emotion
# 2  Positive emotion
# 3  Negative emotion
# 4  Positive emotion

# %% [markdown]
# ## clean tweet text

# %%
# scrub/ clean tweet text with function using regex for lower, punctuation, websites, prep for tokenizing
data['clean_tweet'] = scrub_tweet(data['tweet'])

# %% [markdown]
# # sentiment column clean up

# %%
# update values in sentiment column
data['sentiment'] = data['sentiment'].replace(['Negative emotion'], 'negative')
data['sentiment'] = data['sentiment'].replace(['Positive emotion'], 'positive')
data['sentiment'] = data['sentiment'].replace(['No emotion toward brand or product'], 'neutral')
data['sentiment'] = data['sentiment'].replace(['I can\'t tell'], 'unknown')

# %%
data.sentiment.describe()
# Out:
# count        8014
# unique          4
# top       neutral
# freq         4476
# Name: sentiment, dtype: object

# %%
# assess 'unknown' sentiment values
data.loc[data['sentiment']=='unknown']
# Out:
#                                                   tweet       product  \
# 100   ���  "apple has opened a pop-up store in austi...    apple ipad
# 228   just what america needs. rt   google to launch...        google
# 330   the queue at the apple store in austin is four...         apple
# 357   hope it's better than wave rt   buzz is: googl...        google
# 402   syd #sxsw crew your iphone extra juice pods ha...  apple iphone
# ...                                                 ...           ...
# 8650  it's funny watching a room full of people hold...    apple ipad
# 8662  yeah, we have   , google has nothing on us :) ...        google
# 8667  yes, the google presentation was not exactly w...        google
# 8687  "do you know what apple is really good at? mak...    apple ipad
# 8695  how much you want to bet apple is disproportio...         apple
#
#      sentiment                                        clean_tweet
# 100    unknown     apple has opened pop up store in austin so ...
# 228    unknown  just what america needs rt  google to launch m...
# 330    unknown  the queue at the apple store in austin is four...
# 357    unknown  hope it is better than wave rt  buzz is google...
# 402    unknown  syd sxsw crew your iphone extra juice pods hav...
# ...        ...                                                ...
# 8650   unknown  it is funny watching room full of people hold ...
# 8662   unknown     yeah we have   google has nothing on us   sxsw
# 8667   unknown  yes the google presentation was not exactly wh...
# 8687   unknown   do you know what apple is really good at maki...
# 8695   unknown  how much you want to bet apple is disproportio...
#
# [146 rows x 4 columns]

# %% [markdown]
# # Explore

# %%
fig, ax = plt.subplots(figsize=(18,8))
x = data['product']
hue = data['sentiment']
ax = sns.countplot(x, hue=hue, data=data)
plt.title('Product by Sentiment', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Product by Sentiment')

# %%
data.columns
# Out:
# Index(['tweet', 'product', 'sentiment', 'clean_tweet'], dtype='object')

# %%
brand_df = data.copy()
brand_df.drop(['tweet',  'clean_tweet'], axis=1, inplace=True)

# update values in product column
brand_df.loc[(brand_df['product'].str.contains('apple')), 'product'] = 'apple'
brand_df.loc[(brand_df['product'].str.contains('android')), 'product'] = 'android/google'
brand_df.loc[(brand_df['product'].str.contains('google')), 'product'] = 'android/google'
brand_df.head()
# Out:
#           product sentiment
# 0           apple  negative
# 1           apple  positive
# 2           apple  positive
# 3           apple  negative
# 4  android/google  positive

# %%
fig, ax = plt.subplots(figsize=(18,8))
x = brand_df['product']
hue = brand_df['sentiment']
ax = sns.countplot(x, hue=hue, data=data)
plt.title('Brand by Sentiment', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Brand by Sentiment')

# %%
data['product'].value_counts(normalize=True)
# Out:
# apple ipad      0.301348
# google          0.252433
# apple           0.162965
# apple iphone    0.135887
# apple app       0.063015
# android         0.035313
# google other    0.035188
# android app     0.009608
# apple other     0.004243
# Name: product, dtype: float64

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver', 'orange', 'pink', 'red', 'purple', 'blue', 'yellow', 'brown']
expl = (0, 0.1)
data['product'].value_counts().plot(kind='bar', legend=False, colors=colors)
plt.title('Product Count', fontsize=20)
# Out:
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"
# Text(0.5, 1.0, 'Product Count')

# %%
data['sentiment'].value_counts()
# Out:
# neutral     4476
# positive    2849
# negative     543
# unknown      146
# Name: sentiment, dtype: int64

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver', 'orange', 'pink']
expl = (0, 0.1)
data.sentiment.value_counts().plot(kind='pie', legend=True, startangle=45, shadow=True, 
                             colors=colors, autopct='%1.1f%%')
plt.title('Sentiment Count', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sentiment Count')

# %%
import itertools
# pre cleaned corpus
corpus1 = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.tweet]))
print(len(corpus1))
# Out:
# 179247

# %% [markdown]
# # More Scrubbing

# %% [markdown]
# ## stopwords assessment and removal

# %%
# remove stopwords from tweet text
data['words'] = remove_stop_text(data.clean_tweet)

# %% [markdown]
# ## tokenize, lemmatize, stemming

# %%
#tokenizer = RegexpTokenizer("[\w']+")
stemmer = nltk.stem.SnowballStemmer('english')
tokenizer = TreebankWordTokenizer()
detokenizer = TreebankWordDetokenizer()
lemmatizer = lemmatizer = WordNetLemmatizer()

# %%
# tokenize/stem tweet text
data['tokenized'] = data.words.map(toke_text)
#data['tokens'] = data.tokenized.map(stem_text)
data['tokens'] = [stem_text(tok) for tok in data.tokenized]
data['tokenl'] = [lem_text(tok) for tok in data.tokenized]

data['wordl'] = [detokenizer.detokenize(tok) for tok in data.tokenl]
data['wordss'] = [detokenizer.detokenize(tok) for tok in data.tokens]
data['pos_s'] = data.tokens.map(pos_tag)
data['pos_l'] = data.tokenl.map(pos_tag)

# %%
data.isnull().sum()
# Out:
# tweet          0
# product        0
# sentiment      0
# clean_tweet    0
# words          0
# tokenized      0
# tokens         0
# tokenl         0
# wordl          0
# wordss         0
# pos_s          0
# pos_l          0
# dtype: int64

# %%
# post cleaned corpus for stemmed tokens
corpus_s = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.words]))
print(len(corpus_s))
# Out:
# 64432

# %%
# post cleaned corpus for lemmatized tokens
corpus_l = list(itertools.chain(*[nltk.word_tokenize(tok) for tok in data.wordl]))
print(len(corpus_l))
# Out:
# 64398

# %%
# convert target data with labelencoder
data['target'] = data['sentiment'].map( {'positive':1, 'negative':0, 'neutral':3, 'unknown':4} )

# %% [markdown]
# # further exploration of only positive and negative sentiment

# %% [markdown]
# ## of only positive and negative sentiment

# %%
# create dataframe with only positive and negative sentiment
df = data.copy()
df = df[df['sentiment'].isin(['positive', 'negative']) ]
col = ['wordss', 'tokens', 'wordl', 'tokenl', 'pos_s', 'pos_l', 'sentiment', 'target']
df = df[col]

# %%
# Creating the dicti
word_dict = {} 

for row in df.wordss: 
    words = tokenizer.tokenize(row) 
    for word in words: 
        if word not in word_dict.keys(): 
            word_dict[word] = 1
        else: 
            word_dict[word] += 1
print(len(word_dict))
max(word_dict, key=word_dict.get)
# Out:
# 4295
# 'store'

# %%
# Creating the dicti
word_dict_l = {} 

for row in df.wordl: 
    words = tokenizer.tokenize(row) 
    for word in words: 
        if word not in word_dict_l.keys(): 
            word_dict_l[word] = 1
        else: 
            word_dict_l[word] += 1
print(len(word_dict_l))
max(word_dict_l, key=word_dict_l.get)
# Out:
# 5059
# 'store'

# %%
# print max number of tokens in any row
rows = df.tokens.astype(str)
maxlen=-1
for row in rows:
    tokens = row.split(',')
    token_cnt = len(tokens)
    
    longest_token = max(tokens)
    if(maxlen<len(tokens)):
        maxlen=len(tokens)

print("The maximum number of words in any document is : ",maxlen)
# Out:
# The maximum number of words in any document is :  17

# %% [markdown]
# ##  assess word frequency

# %%
from wordcloud import WordCloud

# %%
# top 50 on stemmed and lemmatized data
terms_total = top_50(df.tokens)
terml_total = top_50(df.tokenl)
# Out:
# 50 MOST common words: [('store', 584), ('app', 545), ('not', 439), ('new', 394), ('get', 237), ('pop', 223), ('launch', 217), ('open', 185), ('go', 184), ('one', 168), ('line', 165), ('time', 164), ('use', 162), ('like', 159), ('parti', 159), ('circl', 158), ('come', 157), ('social', 155), ('win', 151), ('day', 147), ('great', 138), ('via', 134), ('today', 132), ('map', 125), ('cool', 122), ('free', 120), ('love', 118), ('look', 115), ('peopl', 111), ('network', 110), ('good', 107), ('mobil', 107), ('check', 105), ('see', 105), ('awesom', 103), ('need', 97), ('got', 97), ('thank', 91), ('temporari', 89), ('call', 88), ('downtown', 86), ('year', 84), ('think', 84), ('design', 83), ('take', 82), ('make', 80), ('even', 80), ('user', 78), ('mayer', 76), ('first', 75)]
# Total: 4293
# 50 MOST common words: [('store', 584), ('not', 439), ('app', 437), ('new', 394), ('pop', 219), ('get', 199), ('launch', 188), ('one', 168), ('line', 162), ('circle', 158), ('party', 156), ('time', 154), ('like', 152), ('social', 152), ('day', 147), ('great', 138), ('via', 134), ('today', 132), ('win', 122), ('map', 121), ('cool', 121), ('free', 120), ('go', 117), ('people', 111), ('come', 110), ('network', 108), ('apps', 108), ('mobile', 106), ('good', 103), ('need', 97), ('got', 97), ('love', 97), ('awesome', 93), ('opening', 89), ('temporary', 89), ('see', 89), ('check', 87), ('downtown', 86), ('year', 84), ('open', 83), ('going', 79), ('user', 78), ('look', 78), ('even', 78), ('think', 77), ('called', 77), ('mayer', 76), ('first', 75), ('thanks', 75), ('popup', 74)]
# Total: 5057

# %%
pos_df = df[df['sentiment']=='positive']
neg_df = df[df['sentiment']=='negative']

# %%
# top 50 on positive sentiment tokens stemmed and lemmatized 
top_50(pos_df.tokens)
top_50(pos_df.tokenl)
# Out:
# 50 MOST common words: [('store', 538), ('app', 461), ('new', 353), ('not', 280), ('pop', 206), ('get', 203), ('launch', 188), ('open', 176), ('go', 158), ('parti', 152), ('win', 149), ('one', 146), ('time', 142), ('line', 142), ('come', 139), ('use', 132), ('great', 130), ('day', 126), ('social', 125), ('circl', 123), ('via', 122), ('free', 118), ('cool', 118), ('like', 115), ('map', 115), ('today', 112), ('love', 111), ('awesom', 99), ('check', 99), ('mobil', 95), ('good', 93), ('network', 93), ('look', 91), ('got', 90), ('see', 90), ('downtown', 85), ('temporari', 84), ('thank', 83), ('peopl', 82), ('make', 72), ('popup', 72), ('even', 71), ('call', 68), ('mayer', 67), ('year', 67), ('around', 65), ('first', 64), ('market', 64), ('user', 63), ('want', 63)]
# Total: 3699
# 50 MOST common words: [('store', 538), ('app', 379), ('new', 353), ('not', 280), ('pop', 203), ('get', 174), ('launch', 167), ('party', 150), ('one', 146), ('line', 140), ('time', 132), ('great', 130), ('day', 126), ('circle', 123), ('via', 122), ('social', 122), ('win', 120), ('free', 118), ('cool', 117), ('map', 112), ('today', 112), ('like', 109), ('go', 104), ('come', 101), ('mobile', 94), ('love', 91), ('network', 91), ('got', 90), ('awesome', 89), ('good', 89), ('opening', 86), ('downtown', 85), ('temporary', 84), ('check', 83), ('people', 82), ('apps', 82), ('open', 78), ('see', 74), ('popup', 72), ('even', 69), ('thanks', 68), ('mayer', 67), ('year', 67), ('going', 66), ('around', 65), ('first', 64), ('called', 64), ('user', 63), ('need', 62), ('marissa', 59)]
# Total: 4334
# 4334

# %%
from wordcloud import WordCloud

# %%
#plot word cloud
pos_words = []
for t in pos_df.wordl:
    pos_words.append(t)
pos_text = pd.Series(pos_words).str.cat(sep=' ')
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(pos_text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# top 50 on negative sentiment tokens stemmed and lemmatized 
top_50(neg_df.tokens)
top_50(neg_df.tokenl)
# Out:
# 50 MOST common words: [('not', 159), ('app', 84), ('store', 46), ('like', 44), ('new', 41), ('need', 35), ('circl', 35), ('get', 34), ('social', 30), ('use', 30), ('design', 29), ('peopl', 29), ('launch', 29), ('go', 26), ('think', 24), ('look', 24), ('line', 23), ('one', 22), ('time', 22), ('day', 21), ('would', 21), ('take', 21), ('say', 20), ('call', 20), ('today', 20), ('come', 18), ('phone', 18), ('fail', 18), ('year', 17), ('pop', 17), ('network', 17), ('talk', 17), ('headach', 16), ('long', 16), ('product', 16), ('tweet', 15), ('user', 15), ('wait', 15), ('news', 15), ('batteri', 15), ('thing', 15), ('see', 15), ('much', 15), ('compani', 15), ('america', 15), ('back', 14), ('tri', 14), ('money', 14), ('major', 14), ('realli', 14)]
# Total: 1628
# 50 MOST common words: [('not', 159), ('app', 58), ('store', 46), ('like', 43), ('new', 41), ('need', 35), ('circle', 35), ('social', 30), ('people', 29), ('design', 27), ('apps', 26), ('get', 25), ('think', 23), ('line', 22), ('one', 22), ('time', 22), ('launch', 21), ('day', 21), ('would', 21), ('look', 21), ('say', 20), ('today', 20), ('phone', 18), ('year', 17), ('network', 17), ('headache', 16), ('pop', 16), ('long', 16), ('product', 16), ('fail', 16), ('user', 15), ('news', 15), ('battery', 15), ('thing', 15), ('see', 15), ('much', 15), ('company', 15), ('america', 15), ('back', 14), ('money', 14), ('major', 14), ('really', 14), ('good', 14), ('fascist', 14), ('talk', 14), ('going', 13), ('already', 13), ('go', 13), ('called', 13), ('way', 13)]
# Total: 1808
# 1808

# %%
#plot negative word cloud
neg_words = []
for t in neg_df.wordl:
    neg_words.append(t)
neg_text = pd.Series(neg_words).str.cat(sep=' ')
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(neg_text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(width=1600, height=800, max_font_size=200).generate(neg_text)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(11,11))
colors = ['lightblue', 'silver']
expl = (0, 0.1)
df.sentiment.value_counts().plot(kind='pie', legend=True, startangle=45, shadow=True, 
                             colors=colors, autopct='%1.1f%%')
plt.title('Sentiment Count', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sentiment Count')

# %%
tokens = []
for sent in df.wordl:
    print(tokenizer.tokenize(sent))
    tokens.append(tokenizer.tokenize(sent))
# Out:
# ['hr', 'tweeting', 'rise', 'dead', 'need', 'upgrade', 'plugin', 'station']
# ['know', 'awesome', 'app', 'likely', 'appreciate', 'design', 'also', 'giving', 'free', 't']
# ['not', 'wait', 'also', 'sale']
# ['hope', 'year', 'festival', 'not', 'crashy', 'year', 'app']
# ['great', 'stuff', 'fri', 'marissa', 'mayer', 'tim', 'reilly', 'tech', 'book', 'conference', 'matt', 'mullenweg', 'wordpress']
# ['starting', 'ctia', 'around', 'corner', 'googleio', 'hop', 'skip', 'jump', 'good', 'time', 'fan']
# ['beautifully', 'smart', 'simple', 'idea', 'wrote', 'hollergram', 'app']
# ['counting', 'day', 'plus', 'strong', 'canadian', 'dollar', 'mean', 'stock', 'gear']
# ['excited', 'meet', 'show', 'sprint', 'galaxy', 'still', 'running', 'fail']
# ['find', 'start', 'impromptu', 'party', 'not', 'wait', 'til', 'app', 'come']
# ['foursquare', 'ups', 'game', 'time', 'still', 'prefer', 'far', 'best', 'looking', 'app', 'date']
# ['got', 'ta', 'love', 'calendar', 'featuring', 'top', 'party', 'show', 'case', 'check', 'via']
# ['great', 'app']
# ['haha', 'awesomely', 'rad', 'app', 'hollergram']
# ['noticed', 'dst', 'coming', 'weekend', 'many', 'user', 'hour', 'late', 'come', 'sunday', 'morning']
# ['added', 'flight', 'matching', 'people', 'plane', 'airport', 'also', 'downloaded', 'app', 'nicely', 'done']
# ['must', 'app', 'lovely', 'review', 'forbes', 'app', 'holler', 'gram']
# ['need', 'buy', 'not', 'sure', 'need', 'store']
# ['oh', 'god', 'app', 'pure', 'unadulterated', 'awesome', 'easier', 'browse', 'event', 'website']
# ['okay', 'really', 'yay', 'new', 'app', 'kthxbai']
# ['photo', 'installed', 'app', 'really', 'nice']
# ['really', 'enjoying', 'change', 'gowalla', 'looking', 'forward', 'seeing', 'else', 'foursquare', 'sleeve']
# ['looking', 'forward', 'smcdallas', 'pre', 'party', 'wed', 'hoping', 'win', 'resulting', 'shameless', 'promotion', 'chevysmc']
# ['haha', 'awesomely', 'rad', 'app', 'hollergram', 'via']
# ['someone', 'started', 'group', 'group', 'pre', 'great', 'idea']
# ['new', 'sq', 'look', 'like', 'going', 'rock', 'update', 'push', 'tonight', 'keepaustinweird']
# ['right', 'app', 'sweeeeet', 'nice', 'job', 'team']
# ['smart', 'hollergram', 'app', 'may', 'leave', 'vuvuzela', 'home']
# ['must', 'app', 'going', 'hollergram']
# ['best', 'ha', 'first', 'line', 'pop', 'store', 'event', 'planner', 'eventprofs', 'pcma', 'engage']
# ['false', 'alarm', 'circle', 'not', 'coming', 'probably', 'not', 'ever', 'circle', 'social']
# ['great', 'weather', 'greet', 'still', 'need', 'sweater', 'night', 'putting', 'flash', 'store', 'downtown', 'sell']
# ['hand', 'held', 'hobo', 'drafthouse', 'launch', 'hobo', 'shotgun', 'app']
# ['hooray', 'opening', 'pop', 'store']
# ['wooooo', 'store', 'downtown', 'open', 'til', 'midnight']
# ['talking', 'effort', 'allow', 'user', 'open', 'system', 'bettercloud']
# ['st', 'stop', 'chaos', 'hunt', 'java', 'get', 'spy', 'game', 'chance', 'win']
# ['line', 'store', 'insane']
# ['attending', 'design', 'headache']
# ['boooo', 'flipboard', 'developing', 'version', 'not', 'say']
# ['check', 'line', 'power']
# ['come', 'party', 'tonight', 'band', 'food', 'art', 'ice', 'cream', 'nifty', 'interactive', 'map']
# ['holla', 'party', 'best', 'ever', 'get', 'butt']
# ['love', 'case', 'not', 'get', 'phone', 'fail']
# ['new', 'post', 'app', 'make', 'easy', 'connect', 'social', 'network', 'people', 'meet']
# ['nice', 'app', 'behaving', 'today', 'crash', 'yesterday', 'ridiculous']
# ['nice', 'hey', 'fan', 'get', 'peek', 'space', 'slated', 'pop', 'store', 'tomorrow']
# ['one', 'thing', 'great', 'get', 'great', 'earth', 'face', 'company', 'love', 'sxwsi']
# ['thanks', 'mention', 'new', 'speech', 'apps', 'showcased', 'conf', 'sxswh', 'sxsh']
# ['not', 'provide', 'charger', 'changed', 'mind', 'going', 'next', 'year']
# ['xmas', 'shiny', 'new', 'apps', 'new', 'book', 'pop', 'store', 'christmas', 'nerd']
# ['yai', 'new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'cont']
# ['fast', 'fun', 'future', 'presenting', 'search', 'local', 'mobile']
# ['headline', 'must', 'gadget', 'hmm', 'could', 'seen', 'one', 'coming', 'gadget']
# ['know', 'dataviz', 'translates', 'satanic', 'sayin']
# ['launched', 'checkins', 'month', 'ago', 'check', 'in', 'ok', 'check', 'out', 'future', 'bizzy']
# ['tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'tweet', 'panel']
# ['kawasaki', 'not', 'lewis', 'level', 'reasoning', 'continued', 'existence', 'evidence', 'existence', 'god', 'bawling']
# ['kawasaki', 'pagemaker', 'saved', 'oh', 'day', 'jwtatl', 'enchantment', 'via']
# ['spark', 'teamandroid', 'award', 'read']
# ['great', 'thought', 'japan', 'apac', 'region', 'dealing', 'earthquake', 'tsunami', 'trauma']
# ['school', 'marketing', 'expert']
# ['temporary', 'store', 'def', 'not', 'tent', 'powerhouse', 'gym']
# ['temporary', 'store', 'th', 'congress', 'along', 'happy', 'hipster']
# ['win', 'opening', 'temporary', 'store', 'downtown', 'support', 'launch', 'good']
# ['christian', 'devs', 'want', 'talk', 'maybe', 'wk', 'together', 'cool', 'app']
# ['taken', 'storm', 'excited', 'part', 'mobile']
# ['haz', 'ifrom', 'gr']
# ['stack', 'waiting', 'bought', 'got', 'mine', 'hassle', 'handled', 'perfectly']
# ['smallbiz', 'need', 'review', 'play', 'place', 'got', 'app', 'seo']
# ['take', 'major', 'south', 'korean', 'director', 'get', 'make', 'movie', 'entirely']
# ['beautiful', 'store', 'pic']
# ['must', 'app', 'lovely', 'review', 'forbes', 'app', 'holler', 'gram']
# ['temporary', 'store', 'sneaky', 'usual']
# ['beta', 'testing', 'interactive', 'book', 'app', 'moonbot', 'studio', 'louisiana', 'cool', 'app']
# ['day', 'one', 'seeing', 'ton']
# ['store', 'sold', 'everything', 'except', 'gig', 'wifi', 'white', 'manage', 'get']
# ['store', 'sold', 'everything', 'except', 'gig', 'wifi', 'white', 'also', 'known', 'white', 'jean', 'configuration']
# ['offered', 'promo', 'ninjafinder', 'user', 'fan', 'not', 'suck', 'not']
# ['lonelyplanet', 'guide', 'free', 'limited', 'time', 'lp', 'travel']
# ['store', 'still', 'short', 'line']
# ['left', 'tradeshow', 'demo', 'theatre', 'ok', 'get', 'see', 'presenter', 'using']
# ['anyone', 'want', 'make', 'quick', 'hundred', 'dollar', 'new', 'ad', 'hoc', 'store', 'get', 'hundred', 'plus', 'cost']
# ['monday', 'barry', 'diller', 'new', 'york', 'time', 'congress', 'lunch', 'hotel', 'party', 'party', 'six', 'dirty', 'martini', 'monday']
# ['seriously', 'testing', 'mobile', 'apps', 'constant', 'crash', 'causing', 'lost', 'schedule', 'sync', 'wp']
# ['ready', 'apps', 'make', 'ur', 'blogging', 'easier']
# ['conflagration', 'doofusness']
# ['attention', 'er', 'rumored', 'pop', 'temporary', 'store', 'launch', 'need']
# ['went', 'lousy']
# ['winning', 'picture']
# ['spent', 'come', 'already', 'used', 'wait', 'couple', 'city', 'block']
# ['behind', 'email', 'give', 'line', 'composed', 'reply', 'protip']
# ['like', 'pm', 'night', 'line', 'around', 'block', 'popup', 'store', 'selling']
# ['seen', 'wild', 'people', 'say', 'fast', 'still', 'pic', 'terrible']
# ['take', 'video']
# ['many', 'snapping', 'away', 'keynote', 'slide']
# ['new', 'post', 'apps', 'using', 'south', 'southwest', 'interactive']
# ['sweet', 'new', 'map', 'demo', 'going', 'ballroom']
# ['million', 'mile', 'per', 'day', 'driving', 'map', 'navigation']
# ['band', 'want', 'share', 'track', 'audience', 'stage', 'use', 'frostwire', 'wi', 'fi', 'available']
# ['not', 'need', 'car', 'use', 'zimride', 'etc', 'share', 'ride', 'shareable']
# ['picked', 'mophie', 'battery', 'case', 'prep', 'not', 'lugging', 'around', 'laptop', 'using', 'phone', 'huge', 'win', 'last', 'year']
# ['not', 'rumor', 'monger', 'good', 'read', 'circle', 'preview', 'via', 'socbiz', 'fb']
# ['hobo', 'shotgun', 'video', 'game', 'coming', 'user', 'yes', 'please']
# ['build', 'store', 'le', 'hour', 'one', 'biggest', 'launch', 'company', 'history', 'got']
# ['read', 'groupme', 'sound', 'like', 'incredible', 'app', 'available', 'phone', 'yet']
# ['alarm', 'botch', 'timechange', 'many', 'er', 'freak', 'late', 'flight', 'missed', 'panel', 'behind', 'bloody', 'mary']
# ['shout', 'lady', 'holding', 'free', 'show', 'take', 'photo', 'sipping', 'free', 'beer', 'cc']
# ['meant', 'also', 'wish', 'dyac', 'stupid']
# ['rumor', 'store', 'opening', 'th', 'congress', 'sign', 'point', 'yes']
# ['picked', 'pop', 'store', 'minute', 'wait']
# ['brilliant', 'enlightening', 'game', 'mechanic', 'presentation']
# ['marketing', 'sale', 'genius']
# ['need', 'laptop', 'dictaphone', 'vid', 'camera', 'wow', 'love', 'meet', 'real', 'cerebellum', 'charged', 'people']
# ['app', 'ridiculous', 'personal', 'planner', 'next', 'day']
# ['found', 'app', 'kyping', 'geolocation', 'not', 'releasing', 'background', 'need', 'patch', 'batterykiller']
# ['app', 'live', 'rsvp', 'event', 'phone', 'check', 'sundayswagger', 'eventbrite', 'com', 'scoremore']
# ['love', 'app', 'awesome', 'must', 'see', 'app', 'bizzy']
# ['course', 'built', 'temp', 'store', 'texas', 'understand', 'concept', 'corralling', 'cattle', 'pickmeupanipad']
# ['love', 'not', 'let', 'something', 'like', 'not', 'retail', 'store', 'near', 'keep', 'away', 'opening', 'pop', 'store']
# ['surprise', 'opened', 'pop', 'store', 'nerd', 'town', 'get', 'new', 'cnet']
# ['surprise', 'opened', 'pop', 'store', 'nerd', 'town', 'get', 'new', 'ipads', 'cnet']
# ['surprise', 'opened', 'pop', 'store', 'nerd', 'town', 'get', 'new', 'ipads']
# ['great', 'example', 'retail', 'store', 'layed', 'future', 'register', 'checkout', 'line']
# ['opening', 'temporary', 'store', 'downtown', 'launch', 'gswsxsw']
# ['opening', 'temporary', 'store', 'downtown', 'launch', 'oh', 'yay', 'traffic']
# ['popup', 'store', 'open', 'noon', 'fresh', 'shipment', 'pretty', 'sure', 'going', 'get', 'one', 'finger', 'crossed']
# ['technews', 'save', 'set', 'open', 'pop', 'store', 'tech', 'news', 'tech']
# ['school', 'marketing', 'expert']
# ['school', 'marketing', 'expert', 'via']
# ['school', 'marketing', 'expert', 'via', 'true', 'love', 'loathe', 'one', 'marketing', 'like']
# ['school', 'marketing', 'expert', 'cnet']
# ['school', 'marketing', 'expert', 'cnet', 'blog', 'atx', 'retail']
# ['store', 'downtown', 'open', 'til', 'midnight', 'still', 'time']
# ['store', 'mall', 'sunday', 'crowded', 'line', 'fake', 'need', 'fucking', 'dongle', 'genius', 'let']
# ['makeshift', 'store', 'th', 'congress', 'kidding', 'amazing']
# ['temporary', 'store', 'really', 'cool', 'fanboy']
# ['temporary', 'store', 'set', 'shit', 'temptation', 'going', 'control']
# ['temporary', 'store', 'open', 'pm', 'th', 'congress', 'line', 'already', 'growing', 'view', 'io', 'via']
# ['temporary', 'store', 'block', 'office', 'not', 'wait', 'see', 'line', 'tomorrow', 'photo', 'come']
# ['news', 'apps', 'last', 'year']
# ['apps', 'probably', 'need', 'use']
# ['million', 'mobile', 'map', 'user']
# ['new', 'mobile', 'apps', 'using']
# ['apps', 'like', 'software', 'development', 'release', 'start', 'working', 'update']
# ['overheard', 'relaxing', 'computer', 'agreed']
# ['overheard', 'interactive', 'arg', 'hate', 'want', 'blackberry', 'back', 'shocked']
# ['come', 'cool', 'technology', 'one', 'ever', 'heard', 'not', 'go', 'conference']
# ['last', 'year', 'everbody', 'talking', 'year', 'social', 'medium', 'driven', 'revolution', 'year', 'better']
# ['long', 'line', 'pop', 'store', 'great', 'marketing']
# ['people', 'work', 'people', 'rather', 'people', 'work', 'agileagency']
# ['knackered', 'home', 'playing', 'updating', 'timeline', 'smashed', 'partytweets', 'not', 'make', 'go', 'bed']
# ['overheard', 'mdw', 'second', 'halfway', 'battery', 'already', 'not', 'even', 'boarded', 'plane', 'amateurhour']
# ['technews', 'school', 'marketing', 'expert', 'tech', 'news', 'job', 'co', 'tech']
# ['first', 'day', 'fun', 'final', 'presentation', 'doodle', 'googledoodle']
# ['huge', 'line', 'store', 'crowd', 'tripping', 'get', 'new']
# ['ur', 'not', 'aclu', 'party']
# ['laughed', 'spent', 'week', 'hauling', 'macbook', 'everywhere', 'really', 'want', 'shoulder', 'rub']
# ['attendee', 'need', 'qr', 'code', 'reader', 'tweet', 'u', 'image', 'badge', 'first', 'get', 'optiscan', 'free']
# ['hey', 'attendee', 'hop', 'line', 'store', 'four', 'day', 'til', 'new', 'come']
# ['took', 'away', 'lego', 'pit', 'replaced', 'recharging', 'station', 'might', 'check', 'price', 'crap', 'samsung']
# ['bad', 'show', 'late', 'q', 'process', 'poo', 'poos', 'idea', 'leaf', 'early', 'even', 'creative', 'busy', 'gamestorming']
# ['trying', 'balance', 'power', 'power', 'need', 'v', 'suck', 'quick', 'might', 'go', 'airplane', 'mode']
# ['battery', 'winning']
# ['battery', 'not', 'keep', 'tweet', 'thanks', 'precommerce']
# ['fun', 'watch', 'ipadmadness', 'opening', 'pop', 'store']
# ['control', 'set', 'open', 'popup', 'shop', 'core', 'action', 'via', 'cc']
# ['celebrate', 'beauty', 'web', 'msft', 'ie', 'launch', 'play', 'new', 'html', 'game', 'win']
# ['best', 'thing', 'heard', 'weekend', 'gave', 'money', 'japan', 'relief', 'not', 'need']
# ['better', 'time', 'improve']
# ['go', 'beyond', 'earth', 'hour', 'year', 'sharing', 'positive', 'action', 'world', 'download', 'earthhour', 'app']
# ['v', 'bing', 'bettersearch', 'bing', 'shot', 'success', 'structured', 'search', 'potentially', 'higher', 'margin', 'cpa', 'model', 'v']
# ['course', 'bing', 'result', 'good', 'seo', 'qagb']
# ['impulsive', 'buy', 'friend', 'one', 'selling', 'st', 'gen', 'gb']
# ['buying', 'new', 'geekdate']
# ['someone', 'buying', 'present', 'opening', 'pop', 'store']
# ['nice', 'find', 'rsq', 'app']
# ['canadian', 'tuxedo', 'lose', 'hour']
# ['exciting', 'wait', 'opening', 'temporary', 'store', 'downtown', 'launch']
# ['great', 'certain', 'meeting', 'hello', 'holler', 'gram', 'new', 'app', 'hollergram']
# ['dont', 'miss', 'charles', 'chen', 'chromeos', 'access', 'booth', 'exhibit', 'hall', 'pm']
# ['coming', 'guess', 'pretty', 'desperate', 'give', 'attention']
# ['coming', 'sure', 'download', 'go', 'app', 'schedule', 'location', 'event']
# ['seriously', 'considering', 'leaving', 'macbook', 'pro', 'home', 'flying', 'solo', 'week', 'think', 'make', 'work']
# ['shipment', 'daily', 'follow', 'appleatxdt', 'update', 'pop', 'store', 'seems', 'pop']
# ['four', 'day', 'weekend', 'battlela']
# ['dead', 'find', 'secret', 'batphone']
# ['tv', 'demo', 'league', 'extraordinary', 'hacker', 'cool', 'stuff', 'like', 'web', 'apps', 'tv', 'lxh']
# ['best', 'design', 'big', 'chunky', 'element', 'generous', 'space', 'clarity', 'trump', 'density', 'tap', 'quality', 'trump', 'tap', 'quantity', 'tapworthy']
# ['attending', 'designing', 'interface', 'new', 'navigation', 'schema', 'great', 'stuff', 'far']
# ['lovin', 'digital', 'band', 'sings', 'play', 'guitar', 'app', 'fan', 'record', 'vids', 'cnn', 'digital', 'cnngrill']
# ['barry', 'diller', 'think', 'content', 'nut']
# ['really', 'need', 'another', 'big', 'social', 'network', 'right', 'thanks']
# ['japan', 'docomo', 'introduced', 'mobile', 'apps', 'six', 'year', 'came', 'app', 'store', 'jpmobilesummit']
# ['jeez', 'guy', 'dunno', 'pop', 'gold', 'gym', 'realize', 'un', 'job', 'aesthetic']
# ['even', 'begin', 'win', 'tc']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win', 'opening', 'temporary', 'store', 'downtown', 'support', 'launch', 'genius']
# ['even', 'begin', 'win', 'techcrunch']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win', 'via']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win', 'via']
# ['even', 'begin', 'win', 'gon', 'na', 'get', 'sum', 'via']
# ['even', 'begin', 'win', 'techcrunch']
# ['even', 'begin', 'win', 'win', 'big']
# ['even', 'begin', 'win', 'pm']
# ['even', 'begin', 'win', 'tc']
# ['even', 'begin', 'win']
# ['even', 'begin', 'win', 'tc']
# ['even', 'begin', 'win', 'via']
# ['even', 'begin', 'win', 'via']
# ['badgeless', 'event', 'free', 'drink', 'heading', 'free', 'sponsored', 'happy', 'hour', 'semantic', 'web', 'fogo', 'de', 'ch']
# ['best', 'swag', 'ever', 'thanks', 'charging', 'thanks']
# ['timing', 'everything', 'brand', 'winner', 'pnid']
# ['hey', 'exhibitor', 'not', 'capture', 'booth', 'experience', 'retrollect', 'disc', 'popular', 'disc', 'win']
# ['photo', 'far', 'best', 'accessory', 'followed', 'closely', 'margarita']
# ['one', 'fav', 'photo', 'far']
# ['think', 'fell', 'bit', 'love', 'today', 'thanks', 'throwing', 'nerd', 'party', 'speakeasy']
# ['way', 'figure', 'good', 'replacement', 'not', 'making', 'year']
# ['need', 'find', 'better', 'stream', 'follow', 'inane', 'tweet', 'surely', 'not', 'southby']
# ['find', 'hottest', 'spot', 'hot', 'spot', 'app', 'wp']
# ['focusing', 'bridging', 'digital', 'physical', 'divide', 'eg', 'map', 'streetview', 'hotpot', 'autonomous', 'driving']
# ['hey', 'folk', 'please', 'keep', 'u', 'posted', 'circle', 'hope', 'blast']
# ['good', 'news', 'bound', 'fanboys']
# ['wish', 'list', 'tech', 'ntn', 'apps', 'help', 'level', 'playing', 'field', 'kid', 'may', 'not', 'software', 'home']
# ['hitlantis', 'cool', 'song', 'explorer', 'app', 'hitlantis', 'com', 'musicviz']
# ['friend', 'willing', 'pick', 'pay', 'premium', 'dm', 'atl']
# ['good', 'talk', 'akqas', 'interface', 'callback', 'design', 'principle', 'wish', 'go', 'beyond', 'medium', 'marketing', 'example', 'fb']
# ['person', 'front', 'took', 'picture', 'new']
# ['marketing', 'genius', 'open', 'pop', 'store', 'outside']
# ['get', 'ready', 'word', 'circle', 'trending', 'circle', 'social']
# ['get', 'food', 'not', 'forget', 'snap', 'photo', 'win', 'macbook', 'air', 'tv']
# ['getting', 'full', 'underway', 'tell', 'intermittent', 'brick', 'crowded']
# ['giving', 'free', 'lab', 'laptop', 'open', 'source', 'coder', 'attending', 'meet', 'got', 'cupcake']
# ['go', 'app', 'available', 'blackberry', 'window', 'addition']
# ['want', 'go', 'pop', 'store', 'afraid', 'leave', 'new']
# ['omg', 'going', 'macbook', 'pro', 'ipod', 'galaxy', 'tab', 'techgeek']
# ['golden', 'ticket', 'sq', 'party', 'day', 'real', 'party', 'redbullbpm', 'felix', 'da', 'housecat', 'playing']
# ['gsd', 'party', 'blowing', 'mind', 'much', 'amazing', 'food', 'drink', 'music', 'photo', 'booth', 'fun']
# ['circle', 'first', 'real', 'alternative', 'facebook']
# ['let', 'block', 'site', 'not', 'stand', 'blocking', 'look', 'like', 'need']
# ['length', 'penalty', 'based', 'severity', 'breach', 'webmaster', 'guideline', 'white', 'text', 'white', 'bgr', 'might', 'get', 'day', 'pen', 'qagb']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'never', 'beat', 'myspace']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'bigger', 'gaga']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'super', 'interesting']
# ['launch', 'new', 'social', 'network', 'called', 'circle', 'today', 'applause', 'new', 'privacy', 'model', 'attempt']
# ['connect', 'digital', 'physical', 'world', 'mobile']
# ['future', 'contextual', 'discovery', 'location', 'context', 'help', 'u', 'go', 'deeper', 'ever', 'search', 'without', 'search']
# ['check', 'googletv', 'apps', 'connected', 'tv', 'experience', 'connectedtv']
# ['check', 'googletv', 'apps', 'connected', 'tv', 'experience', 'connectedtv', 'fascinating']
# ['cnnmoney', 'got', 'craving', 'mind', 'created', 'app', 'foodspotting', 'apps']
# ['hand', 'awesome', 'dude', 'gave', 'cutsies', 'hour', 'line', 'winning']
# ['smtravel', 'not', 'heard', 'plan', 'launch', 'socnet', 'may', 'circle', 'learned', 'lot', 'year', 'lot', 'changed', 'via']
# ['may', 'not', 'invite', 'cool', 'party', 'two', 'charger', 'pocket', 'happy', 'see']
# ['meeting', 'line', 'popup', 'store', 'love', 'place']
# ['oh', 'lordy', 'go', 'time', 'store', 'open', 'pulling', 'trigger']
# ['loved', 'honesty', 'marissa', 'mayer', 'keynote', 'many', 'product', 'need', 'step', 'customer', 'service', 'location']
# ['hey', 'bout', 'donating', 'spending', 'new', 'japan', 'really', 'need', 'thing']
# ['wondering', 'much', 'revenue', 'store', 'grossed', 'account', 'amid', 'strategic', 'release']
# ['could', 'forget', 'cell', 'phone', 'today', 'fail', 'glad', 'lifelinetotheworld']
# ['hr', 'tweeting', 'rise', 'dead', 'need', 'upgrade', 'plugin', 'station']
# ['feeling', 'worst', 'place', 'try', 'get', 'everyone', 'trying', 'get', 'one', 'techiesunite']
# ['love', 'macbook', 'year', 'one', 'run', 'juice', 'jump', 'next']
# ['holy', 'cow', 'got', 'hooked', 'paolo', 'alex', 'backup', 'charger', 'facebook', 'com', 'powermat', 'powermatteam', 'thanks']
# ['holy', 'cow', 'got', 'hooked', 'paolo', 'alex', 'backup', 'charger', 'facebook', 'com', 'powermat', 'powermattteam', 'thanks']
# ['catch', 'mean']
# ['knew', 'plied', 'beer', 'stogy', 'last', 'night', 'weasel', 'way', 'team', 'party', 'tonight', 'success']
# ['thought', 'would', 'use', 'lot', 'not', 'even', 'touched', 'hmmzies']
# ['convention', 'center', 'today', 'fam', 'showing', 'new', 'game']
# ['beyond', 'frustrated', 'samsung', 'moment', 'runaround', 'leaving', 'att', 'enjoy']
# ['idea', 'startupbus', 'thing', 'addictive', 'also', 'added', 'app']
# ['hot', 'spot', 'data', 'speed', 'could', 'keep', 'also', 'thanks', 'releasing', 'io', 'time']
# ['wondering', 'ppl', 'friday', 'queue', 'convention', 'centre', 'store', 'xd', 'still', 'figuring', 'wot']
# ['week', 'clip', 'join', 'review', 'free', 'go', 'app', 'sxswgo']
# ['room', 'full', 'people', 'good', 'wi', 'fi', 'run', 'frostwire', 'share', 'pic', 'apps', 'vids', 'others']
# ['room', 'full', 'people', 'good', 'wi', 'fi', 'run', 'frostwire', 'share', 'pic', 'apps', 'vids', 'others']
# ['hot', 'spot', 'gowalla', 'right', 'convention', 'cnt', 'ignite', 'party', 'store']
# ['weekend', 'supporting', 'smarty', 'ear', 'launch', 'new', 'apps', 'speech', 'therapy', 'sxswh', 'sxsh']
# ['need', 'sweet', 'mac', 'goodness', 'set', 'temporary', 'store', 'downtown']
# ['zite', 'intelligent', 'magazine', 'deliciousness', 'trending', 'youneedthis']
# ['interested', 'location', 'based', 'tech', 'indoor', 'venue', 'business', 'convention', 'center', 'etc', 'tech', 'need', 'improve', 'first']
# ['tim', 'soo', 'invisible', 'instrument', 'jaw', 'dropping', 'wii', 'controller', 'lovemusicapi']
# ['rockin', 'downtown', 'store']
# ['awesome', 'jailbreak', 'grateful', 'dead', 'fab']
# ['new', 'post', 'launch', 'huge', 'line', 'pop', 'shop']
# ['sold', 'went', 'new', 'buyer', 'report', 'socialmedia', 'tech', 'medium']
# ['remaining', 'stock', 'store', 'come', 'get', 'one']
# ['accessory', 'bag', 'thanks']
# ['app', 'pure', 'gold']
# ['first', 'not', 'even', 'exist', 'last', 'year', 'already', 'feel', 'like', 'pulling', 'antique', 'everytime', 'use']
# ['turn', 'physical', 'messaging', 'platform', 'holler', 'gram', 'cheeky', 'app', 'built']
# ['shoot', 'not', 'display', 'search', 'result', 'go', 'question', 'later', 'osmpw']
# ['pic', 'winning', 'performance', 'accordion', 'toodamnlucky']
# ['fear', 'att', 'g', 'slowpoke', 'network', 'sxswmusic']
# ['app', 'mocking', 'like', 'money', 'come']
# ['app', 'one', 'worst', 'use', 'long', 'time']
# ['cool', 'app', 'launched', 'flypost', 'community', 'bulletin', 'board', 'location', 'learn']
# ['pedicab', 'charger', 'would', 'epic', 'win']
# ['check', 'developer', 'meet']
# ['transient', 'device', 'used', 'short', 'burst', 'pm', 'couch', 'device']
# ['disliking', 'twitter', 'auto', 'shortening', 'link']
# ['clearly', 'positively', 'happily']
# ['flipboard', 'developing', 'version', 'not', 'say']
# ['overheating', 'many', 'british', 'sounding', 'people', 'texas']
# ['part', 'presentation', 'good', 'thing', 'crashing', 'instead', 'work', 'best']
# ['sister', 'throwing', 'party', 'tonigh', 'come', 'band', 'food', 'art', 'ice', 'cream', 'nifty', 'interactive']
# ['wilting', 'stress']
# ['believe', 'almost', 'always', 'use', 'map', 'map', 'use', 'mobile', 'say']
# ['course', 'get', 'store', 'geeksrule']
# ['got', 'ta', 'get', 'hey', 'taariq', 'howdy', 'texas', 'fav', 'app', 'get', 'usguys']
# ['bigger', 'smaller', 'pc', 'good', 'big', 'event', 'like', 'meeti']
# ['bigger', 'smaller', 'pc', 'good', 'big', 'event', 'like', 'meeting', 'day']
# ['bit', 'jealous', 'seeing', 'attendee', 'seems', 'obsolete']
# ['learning', 'thing', 'screen', 'year', 'old', 'explanation', 'instantly', 'knew', 'use']
# ['location', 'pixieengine', 'say', 'future', 'location', 'location', 'location', 'cnn']
# ['keep', 'awake', 'thank', 'god', 'bought']
# ['know', 'week', 'tough', 'already', 'dwindling', 'battery', 'help', 'jeebus', 'keep', 'correcting', 'curse', 'word']
# ['launch', 'social', 'network', 'circle', 'excited']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'via']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'updated', 'not', 'launched', 'soon', 'care']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'brazil', 'orkut', 'user', 'waiting']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'updated']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'surely', 'threat', 'fb']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'pakistan', 'cwc']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'via']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'good']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'via']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'via', 'screenfuture']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today', 'via']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'circle']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'circle']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle']
# ['launch', 'new', 'social', 'network', 'cnet', 'news']
# ['launch', 'new', 'social', 'network', 'circle', 'linking', 'closely', 'peep', 'connect', 'possibly', 'today']
# ['launch', 'product', 'wait', 'launch', 'product', 'exists', 'wait', 'product', 'not', 'exist']
# ['god', 'like', 'imac', 'macbook', 'blackberry', 'staring', 'enough', 'time', 'read', 'book', 'remember']
# ['ha', 'seems', 'like', 'news', 'temporary', 'store', 'wth']
# ['line', 'store', 'day']
# ['saw', 'giant', 'line', 'thought', 'movie', 'premiere', 'store', 'heard', 'scream', 'premiere']
# ['since', 'listening', 'marissa', 'mayer', 'engaging', 'twitter', 'wondering', 'heck', 'happened', 'buzz']
# ['looking', 'forward', 'bing', 'website', 'ranking', 'week']
# ['lot', 'effort', 'helping', 'japan', 'many', 'global', 'issue', 'wtf', 'people']
# ['got', 'ta', 'love', 'unabashed', 'fanboy', 'even', 'begin', 'win']
# ['geeky', 'love', 'opening', 'temporary', 'store', 'downtown', 'launch']
# ['love', 'come', 'cool', 'technology', 'one', 'ever', 'heard', 'not', 'go', 'conference']
# ['love', 'come', 'cool', 'technology', 'one', 'ever', 'heard', 'not', 'go', 'conference']
# ['trying', 'make', 'detailed', 'colour', 'coded', 'calendar', 'proving', 'really', 'tough', 'also', 'get', 'organized']
# ['many', 'people', 'ipads', 'whole', 'room', 'raise', 'hand', 'half', 'room', 'raise', 'hand', 'stillonamacbook', 'shame', 'nfusion']
# ['love', 'marketing', 'genius', 'inside', 'temporary', 'store']
# ['great', 'vid', 'marty', 'live', 'unboxing', 'front', 'store', 'video']
# ['think', 'may', 'go', 'laptop', 'today', 'veteran', 'reason', 'not']
# ['made', 'soundcloud', 'ambassador', 'upload', 'music', 'show', 'reward', 'soundcloud', 'app', 'fresh']
# ['alert', 'medium', 'saw', 'one', 'tablet', 'like', 'finding', 'needle', 'haystack', 'also', 'saw', 'cr']
# ['great', 'mental', 'image', 'people', 'session', 'taking', 'photo', 'air', 'doingitwrong']
# ['purchased', 'mexican', 'mavis', 'boy', 'bear', 'sold', 'first', 'listen', 'thanks', 'itunes', 'free', 'itunes']
# ['think', 'might', 'go', 'weekend', 'without', 'seeing', 'case', 'twice']
# ['sure', 'mine', 'via', 'know', 'agnerd', 'dairy', 'relies', 'evernote', 'agchat']
# ['bummed', 'miss', 'year', 'quarantined', 'kiddie', 'cold', 'garageband', 'comfort', 'fb']
# ['miss', 'knew', 'spotted', 'nfc', 'enabled', 'place', 'marker', 'bird', 'wonder', 'billboard', 'near']
# ['loving', 'morphie', 'juicepack', 'today', 'recharge', 'worth']
# ['brilliant', 'move', 'even', 'begin', 'win']
# ['could', 'murphy', 'usa', 'better', 'serve', 'inside', 'map', 'phone', 'announcing', 'great', 'feature']
# ['not', 'intimate', 'together', 'tapworthy', 'designflaws']
# ['compiling', 'list', 'one', 'doc', 'taking', 'lot', 'longer', 'thought', 'many', 'party', 'many', 'good', 'musician']
# ['day', 'charger', 'kicked', 'bucket', 'heck', 'store', 'within', 'walking', 'distance']
# ['feel', 'unequipped', 'compared', 'everyone', 'else', 'dang']
# ['hm', 'need', 'another', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'mashable']
# ['couple', 'new', 'blog', 'random', 'tip', 'awesome', 'app', 'dev', 'politics', 'behind', 'html']
# ['dude', 'next', 'holding', 'using', 'like', 'trophy', 'lookingforwardtothemusicfest']
# ['hard', 'feeling', 'towards', 'say', 'would', 'make', 'great', 'partner', 'checkins', 'pnid']
# ['not', 'rumor', 'popup', 'store', 'downtown', 'launch', 'smart', 'move', 'many', 'dfcbto']
# ['not', 'launching', 'anything', 'partying', 'circle']
# ['buy', 'not', 'buy', 'even', 'begin', 'win']
# ['farooqui', 'mobile', 'io', 'catching', 'fast', 'grow', 'allow', 'app', 'purchasing', 'gamesfortv']
# ['fear', 'not', 'extended', 'wed', 'last', 'day', 'popup', 'sunday', 'appleatxdt']
# ['nothing', 'teeming', 'sea', 'addict', 'busy', 'twittering', 'ever', 'engage', 'one', 'anoth', 'cont']
# ['not', 'fan', 'new', 'trend', 'audience', 'sharing', 'opinion', 'via', 'holding', 'not', 'listen', 'annoying']
# ['power', 'people', 'spent', 'hundred', 'dollar', 'attend', 'spending', 'day', 'waiting', 'line']
# ['continuum', 'attitude', 'crowdsourcing', 'gap', 'hear', 'tell']
# ['third', 'era', 'logo', 'interactive', 'play', 'space', 'get', 'ready', 'googledoodle', 'gsdm']
# ['highlight', 'day', 'undoubtedly', 'meeting', 'second', 'softball', 'fancrazed', 'preso']
# ['wow', 'lot', 'audience', 'not', 'seen', 'vector', 'panning', 'map', 'mobile', 'gasp', 'appreciation']
# ['tomlinson', 'tx', 'observer', 'say', 'subscription', 'data', 'holding', 'biggest', 'impediment', 'success', 'newsapps']
# ['official', 'app', 'go', 'thanks', 'installed']
# ['technews', 'omg', 'jk', 'kiss', 'slap', 'xoom', 'tech', 'news', 'jk', 'omg', 'tech']
# ['also', 'foodspotting', 'hit', 'app', 'find', 'food', 'crave', 'cnnmoneysxsw']
# ['usa', 'today', 'make', 'good', 'use', 'digital', 'shortcut', 'still', 'looking', 'like', 'newspaper', 'tapworthy']
# ['one', 'hand', 'caramel', 'macchiato', 'ouch', 'hiss', 'hot', 'apparently', 'two', 'pump', 'lava', 'begin', 'tmsxsw']
# ['haz', 'one', 'showed', 'charge', 'anywhere', 'bar', 'charge', 'whole', 'table', 'wanted', 'buy', 'one']
# ['open', 'pop', 'store', 'across', 'street', 'two', 'week', 'umm', 'genius', 'not', 'obvious', 'cough', 'cough']
# ['opened', 'makeshift', 'store', 'available', 'pm', 'today', 'tempted']
# ['hey', 'new', 'app', 'dexteria', 'available', 'like', 'u', 'facebook']
# ['plenty', 'people', 'store', 'line', 'scarfing', 'store', 'others']
# ['nice', 'line', 'outside', 'store', 'guess', 'people', 'want']
# ['packing', 'point', 'showing', 'fragmentation']
# ['party', 'best', 'ever', 'get', 'butt']
# ['hey', 'peep', 'new', 'app', 'voicefeed', 'launched', 'u', 'check', 'let', 'u', 'know', 'think']
# ['planning', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'preview', 'far', 'super', 'positive']
# ['need', 'play', 'game']
# ['left', 'pocket', 'guide', 'hotel', 'not', 'know', 'going', 'cope', 'say', 'usability', 'app']
# ['temporary', 'pop', 'shop', 'nice', 'flipboard', 'upgrade']
# ['pop', 'store', 'joke']
# ['pop', 'store', 'attractive', 'impressive', 'many', 'permanent', 'retail', 'store']
# ['pop', 'store', 'line', 'finally', 'dwindled', 'time', 'check']
# ['popup', 'store', 'hook', 'last', 'night', 'singing', 'dancing', 'high', 'five', 'new', 'purchase']
# ['brilliant', 'pr', 'stunt', 'business', 'idea', 'customer', 'service', 'response', 'one', 'set', 'pop', 'store', 'draw', 'crowd', 'medium', 'revenue']
# ['excellent', 'presentation', 'untapped', 'market', 'site', 'pour', 'poursite', 'accessibility']
# ['pretty', 'sick', 'almost', 'make', 'think', 'need', 'one']
# ['problem', 'living', 'story', 'process', 'creating', 'content', 'not', 'change', 'interface', 'hacknews']
# ['brilliant', 'read', 'attention', 'marketer', 'medium', 'professional', 'not', 'save', 'usguys']
# ['reproducing', 'digitally', 'way', 'organically', 'consume', 'information', 'goggles', 'best', 'example', 'marissameyer']
# ['retiring', 'wine', 'library', 'tv', 'moving', 'onto', 'daily', 'grape', 'get', 'app', 'yr', 'thankyouecon']
# ['reveals', 'average', 'time', 'user', 'spent', 'nyt', 'oscar', 'app', 'min', 'blew', 'mind', 'newsapps']
# ['right', 'app', 'sweeeeet', 'nice', 'job', 'team']
# ['congrats', 'good', 'news', 'eats', 'bbq', 'available', 'itunes', 'bbq']
# ['congrats', 'awesome', 'sxswbuffalo', 'lounge', 'experience', 'complete', 'quibidswin']
# ['congrats', 'yes', 'gowalla', 'win', 'best', 'andoid', 'app', 'team', 'choice', 'award', 'thanks']
# ['like', 'tweet', 'new', 'think', 'speak', 'mark', 'belinsky', 'tweet', 'panel']
# ['law', 'average', 'better', 'buzz', 'circle']
# ['love', 'naomi', 'campbell', 'pop', 'store', 'rage']
# ['new', 'rule', 'ooing', 'ahing', 'new', 'get', 'not', 'big', 'deal', 'everybody', 'one']
# ['hot', 'rumor', 'new', 'social', 'network', 'circle', 'photo', 'video', 'status', 'sharing']
# ['saving', 'user', 'year', 'time', 'gps', 'navigation', 'using', 'alternate', 'route', 'traffic']
# ['wow', 'saw', 'someone', 'using', 'computing', 'device', 'mac', 'rare', 'sighting', 'indeed']
# ['say', 'not', 'connect', 'internet', 'even', 'though', 'wifi', 'work', 'great', 'computer', 'suggestion']
# ['grabbed', 'seat', 'ballroom', 'hear']
# ['ok', 'seen', 'two', 'impressive', 'line', 'since', 'one', 'store', 'yesterday', 'party', 'cc']
# ['setting', 'pop', 'store', 'downtown', 'sell', 'bajillions', 'attendee', 'course']
# ['exclusive', 'shot', 'popup', 'store']
# ['spilled', 'bean', 'next', 'platform', 'flipboard', 'team', 'started', 'working', 'sxflip', 'gr']
# ['jealous', 'new']
# ['impressed', 'far', 'slim', 'form', 'instant', 'ness', 'seen', 'not', 'tried', 'one', 'yet']
# ['many', 'ppl', 'product', 'think', 'head', 'explode', 'message', 'brought', 'via']
# ['social', 'site', 'like', 'delicious', 'often', 'better', 'result', 'bing', 'qagb']
# ['sold', 'st', 'time', 'user']
# ['got', 'exciting', 'thing', 'showing', 'year', 'including', 'drag', 'drop', 'store', 'management']
# ['talked', 'great', 'developer', 'meetup', 'looking', 'forward', 'working', 'androidsxsw']
# ['information', 'morning', 'store', 'getting', 'build', 'two', 'week', 'love', 'jealous']
# ['seen', 'best', 'case', 'ever', 'starting', 'transfer', 'bit', 'book', 'fetishism', 'ipads', 'slowly', 'surely']
# ['spotted', 'man', 'need', 'man', 'need', 'go', 'store']
# ['still', 'least', 'pop', 'store', 'bought', 'one']
# ['store', 'people', 'taking', 'pic']
# ['oh', 'store', 'look', 'home', 'downtown', 'sxtxstate', 'store', 'photo']
# ['would', 'stupid', 'not', 'opening', 'temporary', 'store', 'launch', 'via']
# ['great', 'new', 'support', 'web', 'font']
# ['school', 'marketing', 'expert']
# ['great', 'talk', 'must', 'one', 'not', 'mention']
# ['read', 'selling', 'release', 'day', 'good', 'lord', 'vortex', 'smugness', 'day', 'may', 'unbearable']
# ['bad', 'want', 'go', 'home', 'read', 'reader', 'feed', 'geek']
# ['check', 'dokobots', 'game', 'seems', 'pretty', 'cool', 'geogames', 'tmsxsw']
# ['dangerous', 'apps']
# ['hopefully', 'best', 'thing', 'come', 'not', 'fact', 'people', 'flew', 'pick']
# ['first', 'day', 'exhibit', 'hall', 'open', 'stop', 'emc', 'booth', 'enter', 'win']
# ['check', 'free', 'sampler', 'itunes']
# ['following', 'bing', 'qa', 'session', 'great', 'insight', 'webmaster', 'qagb']
# ['like', 'ipoo', 'app', 'ha', 'chan', 'internet', 'bathroom', 'wall', 'sxswmoot']
# ['pdanet', 'awesome', 'app', 'yet', 'like']
# ['check', 'new', 'app', 'gon', 'na', 'huge', 'next', 'week', 'beyond']
# ['new', 'whrrl', 'app', 'live', 'app', 'store', 'marketplace', 'get', 'hot', 'time']
# ['used', 'ol', 'help', 'brit', 'find', 'hotel', 'gooddeed', 'winning']
# ['must', 'one', 'without', 'someone', 'need', 'make', 'case', 'make', 'original', 'look', 'like', 'new', 'nd', 'gen']
# ['unveiling', 'pop', 'store', 'scarborough', 'building']
# ['star', 'gadget']
# ['went', 'whole', 'day', 'laptop', 'used', 'thing', 'missed', 'ftp', 'cloudapp', 'fast', 'typing', 'skype']
# ['exploring', 'world', 'xml', 'combine', 'earth', 'location', 'individual', 'show', 'time', 'cool']
# ['last', 'year', 'not', 'single', 'public', 'today', 'common', 'laptop', 'not', 'seen', 'tablet']
# ['think', 'would', 'app', 'blackberry', 'gave', 'finger', 'guess', 'carry', 'around', 'lame']
# ['expectation', 'engagement', 'visual', 'social', 'delving', 'experience', 'sxfl']
# ['wow', 'thing', 'insanely', 'thin', 'light', 'hold', 'seriously', 'mosaicxm']
# ['among', 'thing', 'missing', 'aclu', 'dance', 'party']
# ['top', 'thing', 'loved', 'far', 'outbrain', 'groupme']
# ['like', 'think', 'decided', 'sell', 'new', 'based', 'suggestion', 'everyone', 'welcome']
# ['anyone', 'think', 'going', 'walking', 'around', 'old', 'inferior', 'released', 'well', 'wrong']
# ['people', 'store', 'not', 'smell', 'great', 'hereforwork', 'nottheipad']
# ['check', 'new', 'app', 'bizzy', 'using', 'check']
# ['check', 'video', 'get', 'glimpse', 'action', 'like', 'gadget', 'could', 'not', 'resist']
# ['believe', 'good', 'life', 'would', 'much', 'better', 'brainwashed', 'line']
# ['thousand', 'floating', 'around', 'not', 'seen', 'even', 'one', 'single', 'tablet', 'not', 'even', 'one', 'zero']
# ['excellent', 'tip', 'going', 'new', 'guide', 'free', 'march', 'hard', 'beat', 'free', 'lp']
# ['thank', 'letting', 'test', 'drive', 'car', 'store', 'let', 'hope', 'fix', 'phone']
# ['way', 'design', 'headache', 'not', 'sure', 'bloggable', 'sure', 'interesting']
# ['way', 'forgot', 'cleveland', 'hopkins', 'airport', 'others']
# ['listening', 'saying', 'see', 'yelp', 'service', 'going', 'die', 'far', 'interesting']
# ['listening', 'marissa', 'mayer', 'discus', 'new', 'product', 'including', 'hotpot', 'watch', 'yelp']
# ['set', 'open', 'popup', 'shop', 'core', 'action', 'geek', 'need', 'love']
# ['set', 'open', 'popup', 'shop', 'core', 'action', 'going', 'sell']
# ['set', 'open', 'popup', 'shop', 'core', 'action', 'retail']
# ['expecting', 'see', 'flood', 'shiny', 'new', 'today', 'line', 'store', 'around', 'block']
# ['get', 'see', 'fail', 'social', 'another', 'day', 'okay', 'circle', 'debuting', 'today']
# ['listening', 'twit', 'live', 'also', 'went', 'boxee', 'keg', 'party', 'robot', 'event', 'saw', 'tim', 'ferris', 'speak', 'checked', 'ebay', 'hackathon']
# ['going', 'wait', 'know', 'going', 'better']
# ['fond']
# ['attending', 'tv', 'new', 'medium', 'formula', 'success', 'seeing', 'lot', 'around']
# ['two', 'store', 'atx', 'go', 'sale', 'next', 'friday', 'store', 'going', 'busy']
# ['two', 'store', 'week', 'downtown', 'presence', 'change', 'popup', 'store']
# ['know', 'selling', 'weve', 'never', 'talked', 'hate', 'product', 'check', 'heyo']
# ['unloading', 'store', 'corner', 'th', 'congress', 'temp', 'store', 'dis', 'awesome']
# ['pop', 'store', 'not', 'pop', 'genius', 'bar', 'everywhere']
# ['pop', 'store', 'line', 'ridic']
# ['trying', 'update', 'software', 'download', 'app', 'far', 'luck', 'wonder', 'phone', 'mexico']
# ['def', 'could', 'use', 'today', 'tweeting', 'via', 'sorta', 'pretty', 'much', 'sux']
# ['brilliant', 'use', 'case', 'kik', 'concierge', 'service', 'great', 'get', 'add', 'user', 'ask', 'away']
# ['used', 'app', 'example', 'good', 'navigation', 'uxdes']
# ['little', 'need', 'parent', 'anymore', 'comment', 'child', 'playing', 'connectedbrands']
# ['took', 'video', 'th', 'street', 'smart', 'cover', 'rad', 'filming', 'huge', 'display', 'nut', 'look', 'great', 'playback']
# ['dense', 'una', 'vuelta', 'por', 'socialfuel', 'para', 'ver', 'la', 'gran', 'diferencia', 'revolution', 'clumsily', 'translated']
# ['wishing', 'see', 'rumored', 'demo', 'new', 'social', 'network', 'circle', 'via']
# ['better', 'edchat', 'musedchat', 'classical', 'newtwitter']
# ['interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'circle']
# ['interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'circle', 'sound', 'interesting']
# ['giving', 'away', 'creator', 'popular', 'disc', 'interactive', 'create', 'disc', 'share', 'twitter']
# ['weekend', 'release', 'taking', 'part', 'either', 'sadly', 'anybodywanttobuymeanipad']
# ['not', 'cocky', 'perhaps', 'separate', 'store', 'would', 'good', 'idea', 'guess', 'not', 'need', 'extra', 'marketing']
# ['brilliant', 'win', 'win']
# ['winner', 'awesome', 'got', 'via']
# ['impressed', 'articulate', 'relevant', 'fun', 'convention', 'center']
# ['new', 'app', 'resourceful', 'way', 'get', 'connected', 'hashable', 'droid']
# ['disgusted', 'battery', 'life', 'already', 'pm', 'blackberry', 'going', 'strong']
# ['wow', 'witnessed', 'homeless', 'guy', 'giving', 'detailed', 'inventory', 'info', 'passerby', 'popup', 'store']
# ['ouch', 'bing', 'respect', 'bing', 'guy', 'invited', 'fill', 'third', 'chair']
# ['yes', 'gowalla', 'win', 'best', 'andoid', 'app', 'team', 'choice', 'award', 'thanks']
# ['thought', 'social', 'could', 'not', 'get', 'overblown', 'may', 'announcing', 'circle', 'today']
# ['check', 'mom', 'designing', 'boomer']
# ['launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['classiest', 'fascist', 'company', 'america', 'really', 'elegant', 'rji']
# ['mint', 'com', 'confines', 'coding', 'app', 'luxury', 'not', 'worry', 'learning', 'diff', 'phone', 'version', 'gsdm', 'sxswmobileapps']
# ['got', 'copy', 'enchantment', 'kindle', 'today', 'excited', 'thx', 'keeping', 'world', 'enchanted', 'glad']
# ['lack', 'newsworthy', 'announcement', 'unless', 'count', 'circle', 'googlecircles']
# ['new', 'ubersocial', 'app', 'store', 'includes', 'uberguide']
# ['new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'cont']
# ['market', 'comer']
# ['pop', 'ordinance', 'front', 'line', 'admission', 'first', 'step', 'recovery']
# ['pop', 'shop', 'cool']
# ['people', 'work', 'people', 'rather', 'people', 'work', 'agileagency']
# ['lost', 'corrupted', 'crazy', 'hotel', 'good', 'time', 'au', 'bergstrom']
# ['midday', 'mid', 'battery', 'outlet', 'blocked', 'immobile', 'booth', 'serf', 'purpose', 'taunt']
# ['sorry', 'not', 'going', 'party', 'forever']
# ['ning', 'mobile', 'roadie', 'thrilled', 'offer', 'unofficial', 'insider', 'guide', 'fun']
# ['people', 'work', 'people', 'rather', 'people', 'work', 'agileagency']
# ['find', 'start', 'impromptu', 'party', 'not', 'wait', 'til', 'app', 'come']
# ['pop', 'store', 'packed']
# ['oh', 'check', 'new', 'thing', 'strangeproblems']
# ['sweet', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['nice', 'move', 'set', 'open', 'popup', 'shop', 'core', 'action']
# ['big', 'night', 'come', 'party', 'tonight', 'band', 'food', 'art', 'interactive', 'map', 'cc']
# ['novelty', 'news', 'apps', 'fade', 'fast', 'among', 'digital', 'delegate', 'via', 'xipad']
# ['thank', 'picked', 'book', 'killer', 'photoes', 'sxswchi']
# ['good', 'work', 'check', 'latest', 'stream', 'store', 'come', 'playsxsw']
# ['good', 'news', 'eats', 'bbq', 'available', 'itunes', 'bbq']
# ['bout', 'time', 'new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'cont']
# ['good', 'info', 'improve', 'website', 'ranking', 'advice', 'bing']
# ['oh', 'god', 'not', 'rumor', 'opening', 'temporary', 'store', 'downtown', 'launch']
# ['true', 'lost', 'way', 'caring', 'much', 'business', 'v', 'user', 'psych']
# ['cool', 'not', 'rumor', 'open', 'temporary', 'store', 'dt', 'atx', 'launch']
# ['oh', 'snap', 'party', 'hosted']
# ['brilliant', 'marketing', 'opening', 'temporary', 'store', 'downtown', 'next', 'world', 'buy']
# ['brilliant', 'meeting', 'line', 'popup', 'store', 'love', 'place']
# ['congrats', 'yes', 'gowalla', 'win', 'best', 'andoid', 'app', 'team', 'choice', 'award', 'thanks']
# ['love', 'not', 'rumor', 'open', 'temporary', 'store', 'dt', 'atx', 'launch']
# ['well', 'yeah', 'music', 'nerd', 'god', 'cute', 'girl', 'everywhere', 'love', 'interactive', 'end', 'music', 'begin']
# ['shite', 'app', 'new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponso', 'cont']
# ['brilliant', 'setting', 'pop', 'store', 'downtown', 'sell', 'ton', 'attendee', 'course']
# ['brilliant', 'set', 'open', 'popup', 'shop', 'core', 'action', 'going', 'sell']
# ['well', 'done', 'see', 'tonight', 'wrote', 'hollergram', 'app']
# ['finally', 'yeaayyy', 'new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'mashable']
# ['begin', 'story', 'cool', 'app', 'also', 'launching', 'temp', 'store', 'stay', 'tuned', 'love']
# ['wise', 'opening', 'temp', 'store', 'via']
# ['fyi', 'breaking', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'today', 'via', 'socialmedia']
# ['brilliant', 'hope', 'plenty', 'ipads', 'open', 'pop', 'shop', 'report']
# ['new', 'best', 'world', 'pop', 'store', 'invades']
# ['goodguide', 'app', 'scan', 'barcode', 'rank', 'environmental', 'responsibility', 'company', 'nice', 'pressure', 'smmnextgen']
# ['think', 'getting', 'ready', 'order', 'would', 'spend', 'attend']
# ['wow', 'really', 'trying', 'tempt', 'pick', 'tomorrow', 'austintx']
# ['know', 'started', 'lying', 'signal', 'strength']
# ['wow', 'dedication', 'well', 'first', 'line', 'hour', 'go', 'sleepy']
# ['world', 'largest']
# ['nexus', 'mobile', 'useful', 'many', 'ppl']
# ['party', 'maggie', 'maes', 'got', 'free', 'glow', 'dark', 'shade']
# ['scale', 'tiny', 'change', 'even', 'color', 'blue', 'meaningful', 'optimum', 'shade', 'blue', 'link']
# ['hey', 'u', 'go', 'game', 'launch', 'scavenger', 'hunt', 'via', 'see']
# ['hmm', 'not', 'get', 'twitter', 'search', 'update', 'hootsuite', 'tweetdeck']
# ['last', 'day', 'get', 'lp', 'app', 'free', 'travel']
# ['ceo', 'gowalla', 'tell', 'journey', 'blinksale', 'iconbuffet', 'packrat', 'born', 'lightbulb', 'turned']
# ['via', 'store', 'sold', 'everything', 'except', 'gig', 'wifi', 'white']
# ['cnnmoney', 'computing', 'device', 'bigger', 'pas', 'mobile', 'space', 'buzz', 'wssxsw']
# ['look', 'everyone', 'zomg', 'got', 'first', 'day']
# ['get', 'loaded', 'hoot', 'hootsuite', 'mobile', 'update', 'blackberry']
# ['get', 'app', 'yet', 'version', 'schedule']
# ['tried', 'new', 'app', 'beautiful', 'p', 'thanks', 'tvontheradio', 'tix', 'yall', 'rock']
# ['circle', 'new', 'social', 'medium', 'site', 'wow']
# ['study', 'player', 'tell', 'u', 'petting', 'make', 'happy', 'tapworthy']
# ['paper', 'phone', 'mean', 'likely', 'useless', 'well', 'fail']
# ['launch', 'major', 'new', 'social', 'network', 'circle', 'possibly', 'today']
# ['buzz', 'make', 'wish', 'phone', 'beforetwitter', 'would', 'not', 'envy']
# ['set', 'temporary', 'store', 'anyone', 'cc']
# ['love', 'come', 'cool', 'technology', 'one', 'ever', 'heard', 'not', 'go', 'conference']
# ['love', 'come', 'cool', 'technology', 'one', 'ever', 'heard', 'not', 'go']
# ['agree', 'great', 'apps', 'mealtime', 'via', 'bizzy']
# ['yeah', 'detail', 'giveaway', 'coming', 'tonight']
# ['woot', 'first', 'disc', 'market', 'version', 'coming', 'soon']
# ['yay', 'flipboard', 'next', 'platform', 'ceo', 'say']
# ['score', 'handing', 'free', 'pi', 'pi', 'day', 'win']
# ['whoa', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['cool', 'heard', 'pop', 'store', 'downtown', 'pic', 'already', 'gowalla']
# ['nice', 'hey', 'fan', 'get', 'peek', 'space', 'slated', 'pop', 'store', 'tomorrow']
# ['reading', 'book', 'flight', 'guy', 'next', 'reading', 'boom']
# ['haha', 'not', 'waited', 'line', 'product', 'missing', 'important', 'rite', 'passage']
# ['woo', 'hoo', 'finally', 'back', 'il']
# ['lot', 'bigger', 'thought', 'would']
# ['nc', 'buzzing', 'geekdom', 'elevate', 'smart']
# ['yeay', 'new', 'ubersocial', 'app', 'store', 'includes', 'uberguide', 'sponsored', 'masha']
# ['saw', 'morning', 'circle', 'would', 'start', 'rollout', 'not', 'holding', 'breath', 'open', 'minded']
# ['want', 'bad', 'would', 'make', 'live', 'blogging', 'much', 'efficient', 'beautiful', 'case', 'beat', 'leather']
# ['woohoo', 'standing', 'line', 'th', 'time', 'popupstore']
# ['woot', 'spilled', 'bean', 'next', 'platform', 'flipboard', 'team', 'started', 'working', 'sxflip']
# ['thanks', 'love', 'show', 'u', 'via', 'twitpic', 'share', 'love', 'zazzlesxsw']
# ['wishing', 'excellent', 'day', 'today', 'got', 'envy']
# ['wow', 'right', 'thing', 'japan', 'must', 'read']
# ...
# ['mobile', 'activation', 'month', 'taking', 'huge', 'market', 'share', 'sxswmobileapps', 'accesssxsw']
# ['congrats', 'another', 'winner', 'case', 'going', 'mission', 'trip', 'sister', 'haiti', 'cbatsxsw']
# ['congrats', 'executing', 'event', 'guide', 'loaded']
# ['congrats', 'winning', 'last', 'case', 'boyfriend', 'aw', 'cbatsxsw']
# ['san', 'jose', 'surrounded', 'peep', 'every', 'tech', 'nerd', 'dream', 'time', 'turn', 'charm', 'find', 'new', 'bff']
# ['congrats', 'bernd', 'florian', 'launch', 'guguchu', 'ticket', 'terminal', 'app', 'ahead']
# ['start', 'compete', 'bigger', 'guy', 'like', 'checkins', 'pnid']
# ['love', 'get', 'store', 'popping', 'downtown', 'tomorrow', 'lack', 'patience', 'douchebaggery']
# ['thrilled', 'former', 'chief', 'talent', 'officer', 'gap', 'advisory', 'board', 'innotribe']
# ['temp', 'store', 'th', 'congress', 'attendee', 'excuse', 'not', 'walking', 'around']
# ['congrats', 'kenny', 'enjoys', 'spanking', 'new', 'case', 'look', 'happy']
# ['congrats', 'kenny', 'enjoys', 'spanking', 'new', 'case', 'look', 'happy', 'cbatsxsw']
# ['guy', 'next', 'bathroom', 'prop', 'urinal', 'keep', 'using', 'going', 'people', 'serious']
# ['early', 'purchase', 'awesome', 'sweepstakes', 'giveaway', 'game', 'detail', 'coming', 'soon']
# ['yet', 'see', 'someone', 'pc', 'dell', 'otherwise', 'macbook', 'pro', 'ipads']
# ['sell', 'attendee', 'worked', 'sold']
# ['planning', 'wait', 'store', 'get', 'infektd', 'might', 'player', 'crowd']
# ['tattoo', 'chalked', 'pavement', 'mean', 'applefanatic']
# ['toolkit', 'laptop', 'charger', 'bike', 'shade', 'walking', 'ad', 'touch', 'rei', 'sxswtoolkit']
# ['totally', 'digging', 'new', 'foursquare', 'time', 'crap', 'rematch', 'big', 'omaha']
# ['totally', 'mean', 'number', 'company', 'seemed', 'offering', 'thing', 'sad', 'beat', 'give', 'guy']
# ['hotpot', 'not', 'good', 'service', 'force', 'anyways']
# ['hotpot', 'new', 'app', 'let', 'u', 'people', 'rate', 'guess', 'logical', 'business', 'progression', 'marissagoogle']
# ['hotpot', 'rate', 'restaurant', 'get', 'personalized', 'recos', 'eat', 'um', 'think', 'foursquare', 'yelp', 'etc', 'covered', 'already']
# ['hotpot', 'yelp', 'killer', 'impressive', 'integration', 'personalized', 'recommendation', 'really', 'fast']
# ['sound', 'intriguing', 'lot', 'chatter', 'around', 'new', 'social', 'network', 'circle', 'kek']
# ['introducing', 'check', 'status', 'reward', 'mobile']
# ['industry', 'party', 'gsdm', 'grand', 'affair']
# ['thing', 'addition', 'not', 'place', 'print', 'cut', 'newsapps', 'panel']
# ['perfect', 'attention', 'detail', 'recreated', 'code', 'pac', 'man', 'doodle', 'original', 'bug', 'included', 'googledoodles']
# ['better', 'sweet', 'new', 'time']
# ['battery', 'going', 'quickly', 'guy', 'behind', 'let', 'borrow', 'portable', 'charger', 'want', 'one']
# ['stumbling', 'around', 'lost', 'stay', 'contact', 'group', 'application']
# ['future', 'tablet', 'buyer', 'say', 'choose', 'see', 'pop', 'store']
# ['watching', 'twit', 'live', 'want', 'go', 'next', 'year', 'also', 'want', 'content', 'wait', 'awhile', 'always', 'buy', 'technology', 'late', 'anyway']
# ['great', 'visualisation', 'ghost', 'movement', 'logic', 'pacman', 'doodle', 'session', 'detail']
# ['wow', 'suck', 'rebecca', 'black', 'fab']
# ['could', 'search', 'engine', 'instead', 'useful', 'information', 'savebrands']
# ['would', 'great', 'partner', 'u', 'say', 'looking', 'distribution', 'better', 'product']
# ['room', 'full', 'design', 'headache', 'talk']
# ['launch', 'route', 'around', 'traffic', 'offer', 'option', 'keep', 'traffic', 'save', 'yr', 'worth', 'time', 'every', 'day']
# ['found', 'bbq', 'sauce', 'tech', 'texas', 'really', 'come', 'together']
# ['line', 'around', 'block', 'new', 'one', 'lucky', 'recipient']
# ['route', 'around', 'traffic', 'map', 'save', 'user', 'year', 'worth', 'time', 'everyday']
# ['route', 'around', 'traffic', 'map', 'feature', 'saving', 'user', 'year', 'time', 'every', 'day', 'holytrafficjams']
# ['ungrateful', 'much', 'shit', 'play', 'turn', 'shit']
# ['kind', 'funny', 'sad', 'release', 'line', 'longer', 'party', 'line', 'saw', 'last', 'night', 'sheeple']
# ['ad', 'preference', 'view', 'edit', 'think', 'like', 'seenocreepy']
# ['picked', 'mophie', 'charge', 'case', 'tradeshow', 'doubt', 'use', 'time', 'great', 'long', 'day']
# ['picked', 'white', 'today', 'store']
# ['catching', 'hotel', 'room', 'day', 'also', 'tweeting', 'new']
# ['bad', 'news', 'update', 'pop', 'store', 'ipads', 'not', 'sure', 'tomorrow']
# ['another', 'super', 'smart', 'move', 'temporary', 'store']
# ['take', 'really', 'want', 'checkins']
# ['nice', 'gesture', 'lonely', 'planet', 'make', 'guide', 'free']
# ['pressure', 'ahem', 'excuse', 'buy', 'mount', 'must', 'gadget', 'via']
# ['journal', 'momento', 'sale', 'grab']
# ['packed', 'house', 'bing', 'search', 'ranking', 'oh', 'hope', 'catfight', 'qagb']
# ['patented', 'something', 'age', 'domain', 'ranking', 'algorithm', 'not', 'mean', 'use', 'qagb']
# ['use', 'map', 'mobile', 'marissa', 'mayer']
# ['packed', 'house', 'go', 'lynn', 'designing', 'interface', 'new', 'navigation', 'schema', 'uxdes']
# ['used', 'app', 'example', 'good', 'navigation', 'via']
# ['someone', 'held', 'giant', 'like', 'love']
# ['customer', 'service', 'top', 'notch', 'even', 'got', 'guy', 'hanging', 'line', 'giving', 'inventory', 'update', 'nice']
# ['stellar', 'customer', 'service', 'store', 'wish', 'every', 'purchase', 'smooth']
# ['yup', 'showusyouricrazy', 'pop', 'store', 'day', 'release', 'could', 'genius', 'move', 'mktg', 'history']
# ['heading', 'aclu', 'eff', 'party', 'yep', 'throwing', 'back', 'reliving', 'old', 'time', 'fun']
# ['geeking', 'not', 'waited', 'line', 'product', 'missing', 'important', 'rite', 'passage']
# ['route', 'around', 'traffic', 'saving', 'driver', 'year', 'time', 'per', 'day', 'finding', 'best', 'route']
# ['route', 'around', 'traffic', 'pretty', 'sweet', 'route', 'around', 'saving', 'user', 'year', 'day', 'efficient', 'time', 'environment']
# ['auto', 'completes', 'kawasaki', 'name', 'first', 'four', 'letter']
# ['waiting', 'outside', 'store', 'woohoo']
# ['ben', 'benieuwd', 'interrupt', 'regularly', 'scheduled', 'geek', 'programming', 'big', 'news', 'circle']
# ['dev', 'panel', 'indicates', 'screen', 'reader', 'work', 'widget', 'native', 'ui', 'web', 'view', 'browser']
# ['go', 'app', 'live', 'better', 'update', 'schedule', 'sync', 'would', 'love', 'know', 'think']
# ['valuable', 'device', 'far', 'ipod', 'charger']
# ['user', 'drive', 'mile', 'year', 'map', 'navigation', 'jr']
# ['not', 'upgrade', 'newest', 'io', 'yet', 'tweetdeck', 'unstable', 'nten', 'ntc']
# ['fuck', 'love', 'left', 'youtube', 'party', 'maggie', 'maes', 'fun', 'time', 'got', 'youtube', 'tube', 'sock', 'lol']
# ['genius', 'move', 'open', 'temp', 'store', 'downtown', 'via']
# ['wait', 'week', 'not', 'appleatxdt', 'pop', 'shipment', 'daily', 'via']
# ['giveaway', 'full', 'force', 'person', 'friend', 'city', 'end', 'win', 'hint', 'strong', 'email', 'list', 'work', 'well']
# ['not', 'already', 'download', 'free', 'music', 'sampler', 'itunes', 'itunes', 'link', 'good']
# ['not', 'waited', 'line', 'product', 'missing', 'important', 'rite', 'passage']
# ['thank', 'heaven', 'nice', 'traveler', 'got', 'charger', 'another', 'delayed', 'passenger']
# ['bounced', 'catch', 'marissa', 'mayer', 'speak', 'always', 'admired', 'intelligent', 'classy', 'successful', 'girlcrush']
# ['heading', 'shortly', 'record', 'video', 'popup', 'store', 'southby', 'expecting', 'big', 'sale']
# ['totally', 'overshadowing', 'win', 'arrives', 'tomorrow']
# ['porting', 'everything', 'new', 'head', 'sunday', 'syncing', 'song', 'take']
# ['giving', 'away', 'mapper', 'entry', 'amazingly', 'easy', 'detail']
# ['giving', 'away', 'kick', 'time', 'visit', 'fb', 'page', 'info']
# ['photo', 'saving', 'style', 'hpsxsw', 'taken', 'instagram']
# ['got', 'craving', 'mind', 'created', 'app', 'foodspotting', 'apps']
# ['rescuing', 'virtual', 'robot', 'daily', 'life', 'envisioning', 'day', 'last', 'tv', 'broadcast', 'morning']
# ['got', 'vmware', 'talent', 'community', 'app', 'rockin', 'signing', 'talented', 'professional', 'tonight', 'find']
# ['protip', 'avoid', 'area', 'store', 'friday']
# ['auntie', 'voxpop', 'popular', 'apps', 'worth', 'watch', 'not', 'many', 'phone', 'view']
# ['loving', 'new', 'channel']
# ['need', 'loving', 'volunteer']
# ['love', 'alt', 'universe', 'everyone', 'us', 'product', 'fastest', 'way', 'reach', 'someone']
# ['not', 'know', 'user', 'us', 'tv', 'room', 'nobody', 'raise', 'hand', 'packed', 'room', 'socialviewing', 'session']
# ['awesomeness', 'opening', 'temporary', 'store', 'downtown', 'launch']
# ['festival', 'time', 'omg', 'scared', 'got', 'netbook', 'firm', 'droid']
# ['dear', 'goer', 'please', 'look', 'fucking', 'walking', 'hall', 'thanks', 'hipster', 'hilarious']
# ['grateful', 'bicycle', 'back', 'twitter', 'app', 'cursing', 'losing', 'hour', 'zzzs', 'battery', 'life']
# ['dear', 'app', 'suck', 'year', 'sitby', 'u', 'great', 'not', 'include', 'film', 'session']
# ['wow', 'big', 'not', 'attending', 'bringing', 'along', 'temporary', 'store']
# ['free', 'music', 'sampler', 'itunes', 'includes', 'barton', 'hollow', 'open', 'itunes']
# ['free', 'sampler', 'itunes', 'freemusic']
# ['saw', 'someone', 'filming', 'trade', 'show', 'floor', 'teeny', 'hand', 'held', 'steady', 'cam', 'jealous']
# ['free', 'stream', 'downloads', 'via', 'new', 'free', 'winamp', 'app', 'market', 'direct', 'link', 'app', 'download', 'market']
# ['love', 'mac', 'pc', 'ratio', 'like', 'person', 'ratio', 'like', 'three', 'quarter', 'one', 'seriously', 'ton', 'ipads']
# ['know', 'target', 'audience', 'pop', 'shop', 'sell', 'launch', 'day']
# ['popup', 'store', 'sold', 'nothing', 'battery', 'extenders', 'would', 'make', 'much', 'money']
# ['ever', 'doubt', 'influence', 'innovation', 'community', 'look', 'ipads', 'everywhere']
# ['wish', 'free']
# ['looking', 'fwd', 'dj', 'dark', 'party', 'tonight', 'great', 'first', 'day']
# ['right', 'track', 'clever', 'set', 'open', 'popup', 'shop', 'core', 'action']
# ['tight', 'lot', 'friend', 'work', 'employee', 'used', 'work', 'tight', 'tight', 'twitter']
# ['well', 'hope', 'make', 'easier', 'find', 'little', 'want', 'say', 'hi']
# ['wish', 'wish', 'said']
# ['ummmm', 'awesome', 'party', 'djroe', 'store', 'downtown', 'open', 'til', 'midnight']
# ['chance', 'booth', 'selling', 'new']
# ['think', 'presentation', 'nice', 'see', 'retail', 'peep']
# ['going', 'today', 'share', 'photo', 'video', 'ireport', 'cnn', 'app']
# ['wait', 'time', 'lookin', 'like', 'store', 'north', 'already', 'sold', 'word', 'inventory']
# ['debating', 'laptop', 'take', 'rather', 'taking', 'firstworldproblems']
# ['see', 'white', 'know', 'apartment', 'look', 'like', 'need', 'wire']
# ['said', 'not', 'able', 'get', 'opening', 'pop', 'store']
# ['livetapp', 'raffling', 'check', 'tweet', 'show', 'entered', 'win', 'music', 'reward']
# ['thirsty', 'gadget', 'using', 'charge', 'anywhere', 'happy', 'share', 'juice']
# ['jonathan', 'zaggle', 'showed', 'u', 'cool', 'free', 'texting', 'app', 'called', 'zms']
# ['walkin', 'street', 'navigating', 'via', 'tweeting', 'random', 'guy', 'yelping', 'welcome']
# ['umm', 'would', 'keep', 'winning', 'shit', 'thanks', 'killer', 'case']
# ['know', 'game', 'bring', 'people']
# ['hmmm', 'taxi', 'magic', 'not', 'appear', 'magic']
# ['great', 'xml', 'visualization', 'skier', 'using', 'location', 'data']
# ['festivalexplorer', 'app', 'finally', 'solves', 'music', 'musica', 'musiek', 'musique', 'musik', 'app']
# ['even', 'start', 'captured', 'attention', 'whole', 'show', 'win', 'must', 'taking', 'lesson', 'sheen', 'fb']
# ['people', 'brilliant', 'spider', 'secret', 'bryce', 'manor', 'cent', 'right', 'buy']
# ['pdx', 'tomorrow', 'drop', 'note', 'tmsxsw', 'pop', 'retail', 'store', 'epicenter', 'madness']
# ['love', 'opened', 'app', 'party', 'settle', 'argument', 'parenthesis', 'use', 'wordnerd']
# ['group', 'texting', 'war', 'heat', 'fast', 'society', 'launch', 'new', 'app', 'update', 'app']
# ['far', 'mifi', 'rock', 'solid', 'cc']
# ['lovely', 'app', 'get', 'thanks', 'awesome', 'integration']
# ['started', 'planning', 'last', 'night', 'official', 'app', 'solid', 'resource', 'still', 'come', 'short', 'scheduling']
# ['day', 'expected', 'everyone', 'glued', 'included']
# ['best', 'newly', 'added', 'app', 'go', 'awesome', 'come', 'one', 'day', 'one', 'amazing', 'day']
# ['biomimicry', 'basis', 'design', 'problem', 'solving', 'studying', 'flocking', 'swarming', 'behavior', 'understand', 'collab', 'brilliant']
# ['guy', 'talk', 'explaining', 'made', 'realistic', 'twitter', 'bot', 'experiment', 'gee', 'thanks']
# ['leaving', 'bag', 'home', 'today', 'traveling', 'light', 'hand', 'really', 'not', 'need', 'lug', 'around', 'impedimenta']
# ['absolutely', 'beautiful', 'day', 'mall', 'guy', 'track']
# ['way', 'mean', 'get']
# ['think', 'effing', 'hubby', 'line', 'someone', 'point', 'towards', 'line', 'wife', 'number']
# ['friend', 'new', 'photosharing', 'app', 'developed', 'ck', 'show', 'support']
# ['crazy', 'much', 'culture', 'documented', 'doodle']
# ['day', 'geekest', 'place', 'world', 'right', 'yes', 'queue', 'open', 'hidden', 'store']
# ['look', 'interesting', 'launch', 'major', 'new', 'social', 'network', 'called', 'circle', 'possibly', 'today']
# ['look', 'interesting', 'good', 'luck', 'localmind', 'available']
# ['getting', 'store', 'others']
# ['data', 'finally', 'sorted', 'next', 'stop']
# ['dropped', 'macbook', 'pro', 'walking', 'sounding', 'pretty', 'appealing', 'right', 'somehow', 'adapt', 'overcome']
# ['creativity', 'prompt', 'use', 'map', 'virtually', 'take', 'walk', 'used', 'take', 'kid', 'see', 'memory', 'come', 'courtesy']
# ['pretty', 'sure', 'panelist', 'think', 'drowning', 'success', 'fucking', 'insane']
# ['happy', 'discovr', 'named', 'one', 'top', 'ten', 'must', 'apps', 'fight', 'way', 'thru', 'queue']
# ['apparently', 'line', 'get', 'store', 'grew', 'block', 'block', 'past', 'min', 'wut']
# ['apparently', 'app', 'block', 'tweet']
# ['way', 'see', 'tonight', 'hopefully', 'new', 'san', 'francisco', 'international', 'airport', 'sfo']
# ['stopped', 'tron', 'legacy', 'lounge', 'audio', 'sync', 'function', 'extra', 'pretty', 'cool']
# ['second', 'day', 'using', 'really', 'impressed', 'magnetic', 'cover', 'pure', 'brilliance', 'using', 'laptop', 'old', 'school']
# ['way', 'love', 'discus', 'breed', 'midst', 'pre', 'madness']
# ['absolutely', 'timely', 'good', 'schtuff', 'people', 'finder', 'japan', 'quake', 'iqlab']
# ['good', 'job', 'yes', 'gowalla', 'win', 'best', 'andoid', 'app', 'team', 'choice', 'award', 'thanks']
# ['top', 'story', 'school', 'marketing', 'expert', 'thousand', 'town', 'demonstrate', 'social', 'mar']
# ['yep', 'not', 'believe', 'set', 'pop', 'store', 'oh', 'wait', 'yes']
# ['yes', 'picked', 'st', 'one']
# ['yes', 'favorited', 'want', 'win', 'need', 'win', 'doo', 'dah', 'doo', 'dah', 'pushio']
# ['hey', 'anyone', 'signing', 'group', 'texting', 'app', 'groupme', 'got', 'one', 'else', 'kinda', 'useless']
# ['look', 'everyone', 'zomg', 'got', 'first', 'day']
# ['favorite', 'thanks', 'coming', 'getting']
# ['bet', 'man', 'kindle', 'sure', 'pre', 'order', 'amazon']
# ['buy', 'used', 'pick', 'one', 'tomorrow']
# ['could', 'buy', 'new', 'tmrw', 'pop', 'store']
# ['guy', 'ever', 'plan', 'attending', 'need', 'thing', 'skinny', 'jean', 'flannel', 'shirt', 'beard', 'imanoutcast']
# ['might', 'also', 'appreciate', 'new', 'app', 'tweetcaster', 'zip', 'feature', 'let', 'u', 'hide', 'keywords', 'hashtag', 'incl', 'course']
# ['realize', 'still', 'padless', 'gave', 'away', 'case', 'bmm', 'need', 'win', 'next', 'first']
# ['get', 'save', 'back', 'lugging', 'laptop', 'sxswmymistake']
# ['see', 'line', 'front', 'store', 'nothing', 'like', 'tech', 'geek', 'gathering', 'launch', 'day']
# ['know', 'made', 'see', 'bunch', 'grown', 'men', 'hooting', 'getting']
# ['essential', 'mine', 'pocket', 'camera', 'laptop', 'extra', 'cord']
# ['case', 'rad', 'ready', 'stop', 'tomorrow', 'get', 'zazzlesxsw']
# ['pr', 'guy', 'convinced', 'switch', 'back', 'great', 'coverage', 'princess']
# ['papyrus', 'sort', 'like', 'nice', 'lol', 'lavelle']
# ['diller', 'say', 'tv', 'might', 'run', 'playstation', 'xbox', 'essentially', 'ready', 'today', 'diller']
# ['always', 'used', 'camera', 'image', 'stabilizer', 'mode', 'suggestion', 'cam', 'app', 'feature']
# ['everywhere']

# %%
df.head()
# Out:
#                                               wordss  \
# 0     hrs tweet rise dead need upgrad plugin station
# 1  know awesom app like appreci design also give ...
# 2                                 not wait also sale
# 3               hope year festiv not crashi year app
# 4  great stuff fri marissa mayer tim reilli tech ...
#
#                                               tokens  \
# 0  [hrs, tweet, rise, dead, need, upgrad, plugin,...
# 1  [know, awesom, app, like, appreci, design, als...
# 2                            [not, wait, also, sale]
# 3       [hope, year, festiv, not, crashi, year, app]
# 4  [great, stuff, fri, marissa, mayer, tim, reill...
#
#                                                wordl  \
# 0  hr tweeting rise dead need upgrade plugin station
# 1  know awesome app likely appreciate design also...
# 2                                 not wait also sale
# 3             hope year festival not crashy year app
# 4  great stuff fri marissa mayer tim reilly tech ...
#
#                                               tokenl  \
# 0  [hr, tweeting, rise, dead, need, upgrade, plug...
# 1  [know, awesome, app, likely, appreciate, desig...
# 2                            [not, wait, also, sale]
# 3     [hope, year, festival, not, crashy, year, app]
# 4  [great, stuff, fri, marissa, mayer, tim, reill...
#
#                                                pos_s  \
# 0  [(hrs, NN), (tweet, NN), (rise, NN), (dead, JJ...
# 1  [(know, VB), (awesom, JJ), (app, NNS), (like, ...
# 2    [(not, RB), (wait, NN), (also, RB), (sale, NN)]
# 3  [(hope, NN), (year, NN), (festiv, RB), (not, R...
# 4  [(great, JJ), (stuff, NN), (fri, NN), (marissa...
#
#                                                pos_l sentiment  target
# 0  [(hr, NN), (tweeting, VBG), (rise, NN), (dead,...  negative       0
# 1  [(know, VB), (awesome, JJ), (app, NNS), (likel...  positive       1
# 2    [(not, RB), (wait, NN), (also, RB), (sale, NN)]  positive       1
# 3  [(hope, NN), (year, NN), (festival, NN), (not,...  negative       0
# 4  [(great, JJ), (stuff, NN), (fri, NN), (marissa...  positive       1

# %%
y1 = df.target.copy()

# %% [markdown]
# # model

# %%
# import modules for model
from io import StringIO
import random
from keras.utils.np_utils import to_categorical
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, LabelBinarizer
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
from keras import models, layers, optimizers, initializers, callbacks, regularizers
from keras.models import Sequential
from keras.layers import Dense, Flatten, Embedding, Input, Activation, BatchNormalization
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from imblearn.over_sampling import SMOTE
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import gensim
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## functions

# %%
def display_results(y_test, y_pred):
    labels = np.unique(y_pred)
    confusion_mat = confusion_matrix(y_test, y_pred, labels=labels)
    accuracy = (y_pred == y_test).mean()

    print("Labels:", labels)
    print("Confusion Matrix:\n", confusion_mat)
    print("Accuracy:", accuracy)

# %%
def model_results(x):
    results_train = x.evaluate(X_train, y_train)
    print('Training:', results_train)
    results_val = x.evaluate(X_val, y_val)
    print('Validation:', results_val)
    results_test = x.evaluate(X_test, y_test)
    print('Test:', results_test)

# %%
def acc_loss_plot(model_dict):
    acc_values = model_dict['accuracy']
    loss_values =model_dict['loss']

    epochs = range(1, len(loss_values) + 1)

    # Plot the training loss vs the number of epochs
    plt.figure(figsize=(12,9))
    plt.plot(epochs, loss_values, 'b', label='Training loss')

    plt.title('Training loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()


    # Plot the training accuracy vs the number of epochs
    plt.figure(figsize=(12,9))
    plt.plot(epochs, acc_values, 'r', label='Training acc')


    plt.title('Training accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')

    plt.show()

# %%
# assess metrics of model
def get_metrics(y_test, yhat_classes,yhat_probs):
# accuracy: (tp + tn) / (p + n)
    accuracy = accuracy_score(y_test, yhat_classes)
    print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
    precision = precision_score(y_test, yhat_classes)
    print('Precision: %f' % precision)
# recall: tp / (tp + fn)
    recall = recall_score(y_test, yhat_classes)
    print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
    f1 = f1_score(y_test, yhat_classes)
    print('F1 score: %f' % f1)
# ROC AUC
    auc = roc_auc_score(y_test, yhat_probs)
    print('ROC AUC: %f' % auc)
# confusion matrix
    matrix = confusion_matrix(y_test, yhat_classes)
    print(matrix)

# %%
def plot_history(x):
    pd.DataFrame(x.history).plot(figsize=(10, 8))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

# %% [markdown]
# ## PCA data visualization

# %%
# plot PCA visualization of tokens

g_plot = df.copy()
col = ['wordl', 'sentiment']
g_plot = g_plot[col]
X_p = g_plot['wordl']
y_p = g_plot['sentiment']


pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])        
Xp = pipeline.fit_transform(X_p).todense()

pca = PCA(n_components=2).fit(Xp)
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(Xp)

principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])


finalDf = pd.concat([principalDf, g_plot[['sentiment']]], axis = 1)

fig = plt.figure(figsize = (18,12))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['positive', 'negative']
colors = ['r', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['sentiment'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# ## transform data from strings to numeric data

# %% [markdown]
# ## prepare data for model

# %%
# convert target data with labelencoder
le = LabelEncoder()
y = df['target'].copy()
le.fit_transform(y)
# Out:
# array([0, 1, 1, ..., 0, 1, 1])

# %%
X = df.wordl.copy()

# %%
#X = [" ".join(t) for t in df.tokenl]
# split data 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42,
                                                     test_size=.2, stratify=y)
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train,
                                                    test_size=0.1, 
                                                    random_state=42,
                                                    stratify=y_train)

# %%
# verify shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Validation label shape:', np.shape(y_val))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))
print('Validation shape:', np.shape(X_val))
# Out:
# Test label shape: (679,)
# Train label shape: (2441,)
# Validation label shape: (272,)
# Test shape: (679,)
# Train shape: (2441,)
# Validation shape: (272,)

# %%
pipeline = Pipeline([ ('vect', CountVectorizer(ngram_range=(1,2))), 
                     ('tfidf', TfidfTransformer(use_idf=True)), ])
X_train = pipeline.fit_transform(X_train).todense() 
X_test = pipeline.transform(X_test).todense() 
X_val = pipeline.transform(X_val).todense()

# %%
# verify shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Validation label shape:', np.shape(y_val))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))
print('Validation shape:', np.shape(X_val))
# Out:
# Test label shape: (679,)
# Train label shape: (2441,)
# Validation label shape: (272,)
# Test shape: (679, 16802)
# Train shape: (2441, 16802)
# Validation shape: (272, 16802)

# %%
# apply smote to dataset due to imbalance of pos vs neg sentiment
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# summarize the new class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2051, 0: 2051})

# %%
# verify new shape of data
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))


#assign variable to np.shape tuple, width dimension
input_dimension = np.shape(X_train)
count_terms = input_dimension[1]
print(count_terms)
# Out:
# Test label shape: (679,)
# Train label shape: (4102,)
# Test shape: (679, 16802)
# Train shape: (4102, 16802)
# 16802

# %%
# parameters need to be defined, kernel initializers and regularizers applied. 
# assess layer structure, depth and width
# assess neurons 
# batch normalization
# dropout layers
# batch size and epochs
# activation function
# learning rate
# loss function & parameters

# %% [markdown]
# # nn model1

# %%
# initializers with seed for reproducability
# for relu activated layer
initializer = keras.initializers.he_normal(seed=1)

# for tanh layer
initializer2 = keras.initializers.glorot_normal(seed=1)

# regularizer to minimize overfitting
regularizer = keras.regularizers.l2(0.01)

# early stopping callback to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)

#define optimizer and learningrate/learning rate 
nad_opt = optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07)
ad_opt = optimizers.Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=10e-8)
sgd_opt = optimizers.SGD(lr=1e-6, momentum=0.9, nesterov=True)
# Out:
# WARNING:tensorflow:From /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1288: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# create pyramid shaped sequential model

model1_2 = models.Sequential()

# activation layer 
model1_2.add(layers.Dense(500, input_dim=count_terms, activation='relu', 
                          kernel_regularizer=regularizer))
model1_2.add(layers.BatchNormalization(momentum=0.8))   
# add relu activated hidden layers
model1_2.add(layers.Dense(300, activation='relu'))   
# add relu activated hidden layers
model1_2.add(layers.Dense(100, activation='relu'))   
model1_2.add(layers.BatchNormalization(momentum=0.8))   
# add relu activated hidden layers
model1_2.add(layers.Dense(64,))   

model1_2.add(layers.Dense(6, ))  

# output layer with sigmoid activation for binary target
model1_2.add(layers.Dense(1, activation='sigmoid'))


nad_opt = optimizers.Nadam(lr=1e-5, beta_1=0.9, beta_2=0.999)
# use bce loss function for binary classification 
model1_2.compile(optimizer=nad_opt, loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
# Train the model 
predictions1_2 = model1_2.fit(X_train,
                    y_train,
                    epochs=300,
                    callbacks=[es_callback],
                    batch_size=72,
                    validation_data=(X_val, y_val),
                    shuffle=True
                    )
# Out:
# Train on 4102 samples, validate on 272 samples
# Epoch 1/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 8.4587 - accuracy: 0.9659 - val_loss: 8.6925 - val_accuracy: 0.7794
# Epoch 2/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 8.0897 - accuracy: 0.9863 - val_loss: 8.3322 - val_accuracy: 0.8125
# Epoch 3/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.7561 - accuracy: 0.9944 - val_loss: 8.0325 - val_accuracy: 0.8199
# Epoch 4/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.4505 - accuracy: 0.9966 - val_loss: 7.7522 - val_accuracy: 0.8199
# Epoch 5/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 7.1629 - accuracy: 0.9983 - val_loss: 7.4767 - val_accuracy: 0.8382
# Epoch 6/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6.8942 - accuracy: 0.9978 - val_loss: 7.2204 - val_accuracy: 0.8456
# Epoch 7/300
# 4102/4102 [==============================] - 10s 2ms/step - loss: 6.6395 - accuracy: 0.9983 - val_loss: 6.9791 - val_accuracy: 0.8272
# Epoch 8/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 6.3970 - accuracy: 0.9980 - val_loss: 6.7463 - val_accuracy: 0.8456
# Epoch 9/300
# 4102/4102 [==============================] - 9s 2ms/step - loss:
300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0302 - accuracy: 0.9980 - val_loss: 0.7673 - val_accuracy: 0.8860
# Epoch 221/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0318 - accuracy: 0.9968 - val_loss: 0.7786 - val_accuracy: 0.8824
# Epoch 222/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0314 - accuracy: 0.9963 - val_loss: 0.8869 - val_accuracy: 0.8787
# Epoch 223/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0293 - accuracy: 0.9973 - val_loss: 0.9001 - val_accuracy: 0.8824
# Epoch 224/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0295 - accuracy: 0.9971 - val_loss: 0.8302 - val_accuracy: 0.8750
# Epoch 225/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0289 - accuracy: 0.9973 - val_loss: 0.8243 - val_accuracy: 0.8750
# Epoch 226/300
# 4102/4102 [==============================] - 9s 2ms/step - loss: 0.0284 - accuracy: 0.9973 - val_loss: 0.8125 - val_accuracy: 0.8750

# %%
model1_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 500)               8401500
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 500)               2000
# _________________________________________________________________
# dense_2 (Dense)              (None, 300)               150300
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               30100
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100)               400
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                6464
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 390
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 8,591,161
# Trainable params: 8,589,961
# Non-trainable params: 1,200
# _________________________________________________________________

# %%
m1_dict2 =  predictions1_2.history
m1_dict2.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plot_history(predictions1_2)

# %%
acc_loss_plot(m1_dict2)

# %%
model_results(model1_2)
# Out:
# 4102/4102 [==============================] - 2s 560us/step
# Training: [0.02576924415295267, 0.9985373020172119]
# 272/272 [==============================] - 0s 530us/step
# Validation: [0.8125208616256714, 0.875]
# 679/679 [==============================] - 0s 658us/step
# Test: [0.9240215632279948, 0.8792341947555542]

# %%
# predict probabilities for test set
yhat_probs = model1_2.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model1_2.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# assess metrics of model
get_metrics(y_test, yhat_classes, yhat_probs)
# Out:
# Accuracy: 0.879234
# Precision: 0.889776
# Recall: 0.977193
# F1 score: 0.931438
# ROC AUC: 0.793264
# [[ 40  69]
#  [ 13 557]]

# %% [markdown]
# ## nn_model #2

# %%
regularizer2 = keras.regularizers.l2(0.01)

# %%
# create pyramid shaped sequential model
model2 = models.Sequential()
# activation layer 
model2.add(layers.Dense(300, input_dim=count_terms, activation='relu', 
                       kernel_initializer=initializer, kernel_regularizer=regularizer, ))
model2.add(layers.BatchNormalization(momentum=0.7))
# add relu activated hidden layers
model2.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizer, 
                       ))   
# output layer with sigmoid activation for binary target
model2.add(layers.Dense(1, activation='sigmoid'))# create sequential model

# %%
# Compile the model
# early stopping to prevent overfitting changed to training loss rather than val_loss
es_callback = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=10)

# optimizer
ad_opt = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999)

# use bce loss function for binary classification 
model2.compile(optimizer=ad_opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model 
predictions3 = model2.fit(X_train,
                    y_train,
                    epochs=300,
                    callbacks=[es_callback],
                    batch_size=100,
                    validation_data=(X_val, y_val),
                    shuffle=True
                    )
# Out:
# Train on 4102 samples, validate on 272 samples
# Epoch 1/300
# 4102/4102 [==============================] - 4s 1ms/step - loss: 2.2340 - accuracy: 0.9191 - val_loss: 0.9697 - val_accuracy: 0.8971
# Epoch 2/300
# 4102/4102 [==============================] - 3s 814us/step - loss: 0.4995 - accuracy: 0.9907 - val_loss: 0.6542 - val_accuracy: 0.8860
# Epoch 3/300
# 4102/4102 [==============================] - 4s 866us/step - loss: 0.3110 - accuracy: 0.9878 - val_loss: 0.5311 - val_accuracy: 0.8787
# Epoch 4/300
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 5,061,429
# Trainable params: 5,060,829
# Non-trainable params: 600
# _________________________________________________________________

# %%
model2_dict = predictions3.history
model2_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plot_history(predictions3)

# %%
acc_loss_plot(model2_dict)

# %%
# Print the loss and accuracy for the training set 
model_results(model2)
# Out:
# 4102/4102 [==============================] - 1s 303us/step
# Training: [0.08251676907166221, 0.9973183870315552]
# 272/272 [==============================] - 0s 305us/step
# Validation: [0.5667640286333421, 0.8566176295280457]
# 679/679 [==============================] - 0s 351us/step
# Test: [0.5642342014411061, 0.8807069063186646]

# %%
# predict probabilities for test set
yhat_probs = model2.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model2.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
# assess metrics for model
get_metrics(y_test, yhat_classes, yhat_probs)
# Out:
# Accuracy: 0.880707
# Precision: 0.896272
# Recall: 0.970175
# F1 score: 0.931761
# ROC AUC: 0.822195
# [[ 45  64]
#  [ 17 553]]

# %% [markdown]
# ## nn model 3

# %%
# create sequential model
model3 = models.Sequential()

# activation layer 
model3.add(layers.Dense(312, input_dim=count_terms, activation='relu',
                        kernel_regularizer=regularizer2))
model3.add(layers.BatchNormalization(momentum=0.8))
model3.add(layers.Dense(96,  activation='relu',))
model3.add(layers.Dense(32,  activation='relu',))
model3.add(layers.BatchNormalization(momentum=0.8))
model3.add(layers.Dense(10,  activation='relu',))
# output layer with sigmoid activation for binary target
model3.add(layers.Dense(1, activation='sigmoid'))

# %%
es_callback = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=10)
# optimizer
nad_opt = optimizers.Nadam(lr=1e-5, beta_1=0.9, beta_2=0.999)
# compile model
model3.compile(optimizer=nad_opt, loss="binary_crossentropy", metrics=['accuracy'])

# %%
# Train the model 
predictions4 = model3.fit(X_train,
                    y_train,
                    epochs=256,
                    callbacks=[es_callback],
                    batch_size=72,
                    validation_data=(X_val, y_val),
                    shuffle=True
                         )
# Out:
# Train on 4102 samples, validate on 272 samples
# Epoch 1/256
# 4102/4102 [==============================] - 7s 2ms/step - loss: 6.6630 - accuracy: 0.5534 - val_loss: 6.4232 - val_accuracy: 0.6654
# Epoch 2/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 6.2068 - accuracy: 0.7209 - val_loss: 6.1087 - val_accuracy: 0.7426
# Epoch 3/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 5.8577 - accuracy: 0.8491 - val_loss: 5.8548 - val_accuracy: 0.7610
# Epoch 4/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 5.5742 - accuracy: 0.9057 - val_loss: 5.6289 - val_accuracy: 0.7868
# Epoch 5/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 5.3222 - accuracy: 0.9451 - val_loss: 5.4298 - val_accuracy: 0.7868
# Epoch 6/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 5.0975 - accuracy: 0.9654 - val_loss: 5.2188 - val_accuracy: 0.8015
# Epoch 7/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.8901 - accuracy: 0.9790 - val_loss: 5.0262 - val_accuracy: 0.8382
# Epoch 8/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.7024 - accuracy: 0.9846 - val_loss: 4.8629 - val_accuracy: 0.8235
# Epoch 9/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.5256 - accuracy: 0.9902 - val_loss: 4.6858 - val_accuracy: 0.8456
# Epoch 10/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.3606 - accuracy: 0.9924 - val_loss: 4.5397 - val_accuracy: 0.8456
# Epoch 11/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.2041 - accuracy: 0.9949 - val_loss: 4.4040 - val_accuracy: 0.8346
# Epoch 12/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 4.0577 - accuracy: 0.9951 - val_loss: 4.2496 - val_accuracy: 0.8529
# Epoch 13/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 3
256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.1222 - accuracy: 0.9980 - val_loss: 0.4845 - val_accuracy: 0.8787
# Epoch 104/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.1171 - accuracy: 0.9978 - val_loss: 0.4597 - val_accuracy: 0.8824
# Epoch 105/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.1112 - accuracy: 0.9985 - val_loss: 0.4542 - val_accuracy: 0.8787
# Epoch 106/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.1061 - accuracy: 0.9980 - val_loss: 0.4617 - val_accuracy: 0.8824
# Epoch 107/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.1015 - accuracy: 0.9980 - val_loss: 0.4513 - val_accuracy: 0.8824
# Epoch 108/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0967 - accuracy: 0.9983 - val_loss: 0.4614 - val_accuracy: 0.8787
# Epoch 109/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0923 - accuracy: 0.9978 - val_loss: 0.4625 - val_accuracy: 0.8750
# Epoch 110/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0876 - accuracy: 0.9983 - val_loss: 0.4545 - val_accuracy: 0.8787
# Epoch 111/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0839 - accuracy: 0.9985 - val_loss: 0.4615 - val_accuracy: 0.8787
# Epoch 112/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0795 - accuracy: 0.9985 - val_loss: 0.4286 - val_accuracy: 0.8897
# Epoch 113/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0763 - accuracy: 0.9983 - val_loss: 0.4285 - val_accuracy: 0.8860
# Epoch 114/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0727 - accuracy: 0.9985 - val_loss: 0.4281 - val_accuracy: 0.8897
# Epoch 115/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0698 - accuracy: 0.9980 - val_loss: 0.4408 - val_accuracy: 0.8824
# Epoch 116/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0673 - accuracy: 0.9980 - val_loss: 0.4275 - val_accuracy: 0.8860
# Epoch 117/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0642 - accuracy: 0.9980 - val_loss: 0.4621 - val_accuracy: 0.8713
# Epoch 118/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0613 - accuracy: 0.9980 - val_loss: 0.4311 - val_accuracy: 0.8860
# Epoch 119/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0589 - accuracy: 0.9980 - val_loss: 0.4142 - val_accuracy: 0.8934
# Epoch 120/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0563 - accuracy: 0.9973 - val_loss: 0.4441 - val_accuracy: 0.8787
# Epoch 121/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0540 - accuracy: 0.9980 - val_loss: 0.4355 - val_accuracy: 0.8860
# Epoch 122/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0526 - accuracy: 0.9983 - val_loss: 0.4429 - val_accuracy: 0.8824
# Epoch 123/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0500 - accuracy: 0.9983 - val_loss: 0.4450 - val_accuracy: 0.8860
# Epoch 124/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0476 - accuracy: 0.9985 - val_loss: 0.4671 - val_accuracy: 0.8787
# Epoch 125/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0457 - accuracy: 0.9983 - val_loss: 0.4478 - val_accuracy: 0.8897
# Epoch 126/256
# 4102/4102 [==============================] - 6s 1ms/step - loss: 0.0442 - accuracy: 0.9983 - val_loss: 0.4473 - val_accuracy: 0.8897

# %%
model3_dict = predictions4.history
model3_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
model_results(model3)
# Out:
# 4102/4102 [==============================] - 1s 353us/step
# Training: [0.041886442948018326, 0.9985373020172119]
# 272/272 [==============================] - 0s 348us/step
# Validation: [0.44734010626288023, 0.8897058963775635]
# 679/679 [==============================] - 0s 354us/step
# Test: [0.5042606863427759, 0.8659793734550476]

# %%
plot_history(predictions4)

# %%
acc_loss_plot(model3_dict)

# %%
# Output (probability) predictions for the train set 
y_hat_train = model3.predict(X_train)

# %%
# predict probabilities for test set
yhat_probs = model3.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model3.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
get_metrics(y_test, yhat_classes,yhat_probs)
# Out:
# Accuracy: 0.865979
# Precision: 0.883200
# Recall: 0.968421
# F1 score: 0.923849
# ROC AUC: 0.842371
# [[ 36  73]
#  [ 18 552]]

# %% [markdown]
# # nn model no SMOTE, use weights

# %%
# prepare data
X = df.wordl.copy()

y1 = df['target'].astype('category')
# split data 
X3_train, X3_test, y3_train, y3_test = train_test_split(X, y1, random_state=42,
                                                     test_size=.2, stratify=y1)

# split data 
X3_train, X3_val, y3_train, y3_val = train_test_split(X3_train, y3_train, random_state=42,
                                                     test_size=.1, stratify=y3_train)
# build TFIDF features on tweet with tfidf vectorizer
tfv = TfidfVectorizer(min_df=0.0, max_df=1.0, ngram_range=(1,2), use_idf=True
                     )
X_train_trans = tfv.fit_transform(X3_train)
xdf = pd.DataFrame(X_train_trans[0].T.todense(),
index=tfv.get_feature_names(), columns=["term"])
xdf = xdf.sort_values('term', ascending=False)
print (xdf.head(25))
X_val_trans = tfv.transform(X3_val)
test_features = tfv.transform(X3_test)
X3_train = X_train_trans.copy()
X3_test = test_features.copy()
X3_val = X_val_trans.copy()
# Out:
#                        term
# heard not          0.270758
# cool technology    0.268724
# technology one     0.268724
# go conference      0.266773
# not go             0.264898
# ever heard         0.264898
# one ever           0.264898
# come cool          0.264898
# conference         0.253504
# technology         0.244309
# heard              0.241977
# ever               0.236602
# cool               0.211181
# come               0.211181
# go                 0.207724
# one                0.192605
# not                0.149960
# policy             0.000000
# police user        0.000000
# police             0.000000
# pointer hilarious  0.000000
# possibly           0.000000
# pointer            0.000000
# point towards      0.000000
# point totally      0.000000

# %%
# verify shape of data
print('Test label shape:', np.shape(y3_test))
print('Validation label shape:', np.shape(y3_val))
print('Train label shape:', np.shape(y3_train))
print('Test shape:', np.shape(X3_test))
print('Validation shape:', np.shape(X3_val))
print('Train shape:', np.shape(X3_train))
#assign variable to np.shape tuple, width dimension
input_dimension = np.shape(X3_train)
count_terms = input_dimension[1]
# Out:
# Test label shape: (679,)
# Validation label shape: (272,)
# Train label shape: (2441,)
# Test shape: (679, 16802)
# Validation shape: (272, 16802)
# Train shape: (2441, 16802)

# %%
# get class weights for use in model in lieu of smote
from sklearn.utils import class_weight
class_weights = class_weight.compute_class_weight('balanced', np.unique(y3_train), y3_train)
print(class_weights)
# Out:
# [3.12948718 0.59507557]

# %%
# create pyramid shaped sequential model
model4 = models.Sequential()
# activation layer 
model4.add(layers.Dense(300, input_dim=count_terms, activation='relu', 
                       kernel_initializer=initializer, kernel_regularizer=regularizer, ))
model4.add(layers.BatchNormalization(momentum=0.7))
# add relu activated hidden layers
model4.add(layers.Dense(64, activation='relu', kernel_regularizer=regularizer, 
                       ))   
# output layer with sigmoid activation for binary target
model4.add(layers.Dense(1, activation='sigmoid'))

# %%
# early stopping callback to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', min_delta= 0.001, patience=7)
# use bce loss function for binary classification and default adagrad optimizerparameters
model4.compile(optimizer='Adagrad', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model 
predictions5 = model4.fit(X3_train,
                    y3_train,
                    epochs=200,
                    callbacks=[es_callback],
                    batch_size=72,
                    class_weight={1:3.1, 0:0.60},
                    validation_data=(X3_val, y3_val),
                    shuffle=True                    
                    )
# Out:
# Train on 2441 samples, validate on 272 samples
# Epoch 1
# 2441/2441 [==============================] - 2s 848us/step - loss: 0.0737 - accuracy: 0.9971 - val_loss: 0.4421 - val_accuracy: 0.8971
# Epoch 22/200
# 2441/2441 [==============================] - 2s 839us/step - loss: 0.0700 - accuracy: 0.9971 - val_loss: 0.4598 - val_accuracy: 0.8897
# Epoch 23/200
# 2441/2441 [==============================] - 2s 862us/step - loss: 0.0676 - accuracy: 0.9971 - val_loss: 0.4717 - val_accuracy: 0.8860
# Epoch 24/200
# 2441/2441 [==============================] - 2s 861us/step - loss: 0.0697 - accuracy: 0.9971 - val_loss: 0.4486 - val_accuracy: 0.8934
# Epoch 25/200
# 2441/2441 [==============================] - 2s 857us/step - loss: 0.0675 - accuracy: 0.9971 - val_loss: 0.4417 - val_accuracy: 0.8934

# %%
model4.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 300)               5040900
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 300)               1200
# _________________________________________________________________
# dense_18 (Dense)             (None, 64)                19264
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 5,061,429
# Trainable params: 5,060,829
# Non-trainable params: 600
# _________________________________________________________________

# %%
model4_dict = predictions5.history
model4_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plot_history(predictions5)

# %%
acc_loss_plot(model4_dict)

# %%
# Print the loss and accuracy for the training set 
results_train = model4.evaluate(X3_train, y3_train)
results_train
# Out:
# 2441/2441 [==============================] - 1s 279us/step
# [0.06278233298637348, 0.9971323013305664]

# %%
results_val = model4.evaluate(X3_val, y3_val)
results_val
# Out:
# 272/272 [==============================] - 0s 286us/step
# [0.44170035509502187, 0.8933823704719543]

# %%
# Output (probability) predictions for the train set 
y_hat_train = model4.predict(X3_train)

# %%
# Print the loss and accuracy for the test set 
results_test = model4.evaluate(X3_test, y3_test)
results_test
# Out:
# 679/679 [==============================] - 0s 268us/step
# [0.5389108794778366, 0.8836524486541748]

# %%
# predict probabilities for test set
yhat_probs = model4.predict(X3_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model4.predict_classes(X3_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]

# %%
get_metrics(y3_test, yhat_classes,yhat_probs)
# Out:
# Accuracy: 0.883652
# Precision: 0.891547
# Recall: 0.980702
# F1 score: 0.934002
# ROC AUC: 0.830839
# [[ 41  68]
#  [ 11 559]]

# %% [markdown]
# ## model and assess using statistical methods

# %% [markdown]
# # use best performing model on this data

# %%
p6 = model1_2.fit(X3_train,
                    y3_train,
                    epochs=500,
                    callbacks=[es_callback],
                    batch_size=100,
                    class_weight={1:3.1, 0:0.60},
                    validation_data=(X3_val, y3_val),
                    shuffle=True
                         )
# Out:
# Train on 2441 samples, validate on 272 samples
# Epoch 1/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.8626 - accuracy: 0.8984 - val_loss: 0.9356 - val_accuracy: 0.7868
# Epoch 2/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.7347 - accuracy: 0.9230 - val_loss: 0.5951 - val_accuracy: 0.8897
# Epoch 3/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.2204 - accuracy: 0.9816 - val_loss: 0.5756 - val_accuracy: 0.8860
# Epoch 4/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0943 - accuracy: 0.9971 - val_loss: 0.5905 - val_accuracy: 0.8934
# Epoch 5/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0751 - accuracy: 0.9975 - val_loss: 0.5720 - val_accuracy: 0.8860
# Epoch 6/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0776 - accuracy: 0.9967 - val_loss: 0.5820 - val_accuracy: 0.8897
# Epoch 7/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0651 - accuracy: 0.9980 - val_loss: 0.6178 - val_accuracy: 0.8860
# Epoch 8/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0658 - accuracy: 0.9971 - val_loss: 0.6449 - val_accuracy: 0.8824
# Epoch 9/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0638 - accuracy: 0.9971 - val_loss: 0.5913 - val_accuracy: 0.8897
# Epoch 10/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0605 - accuracy: 0.9980 - val_loss: 0.6151 - val_accuracy: 0.8860
# Epoch 11/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0659 - accuracy: 0.9971 - val_loss: 0.6632 - val_accuracy: 0.8824
# Epoch 12/500
# 2441/2441 [==============================] - 4s 2ms/step - loss: 0.0527 - accuracy: 0.9975 - val_loss: 0.5909 - val_accuracy: 0.8897

# %%
# predict probabilities for test set
yhat_probs = model1_2.predict(X3_test, verbose=0)
# predict crisp classes for test set
yhat_classes = model1_2.predict_classes(X3_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]
get_metrics(y3_test, yhat_classes,yhat_probs)
# Out:
# Accuracy: 0.874816
# Precision: 0.893031
# Recall: 0.966667
# F1 score: 0.928391
# ROC AUC: 0.759979
# [[ 43  66]
#  [ 19 551]]

# %%
# summarize the  class distribution
counter = Counter(y_train)
print(counter)
# Out:
# Counter({1: 2051, 0: 2051})

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import average_precision_score, precision_recall_curve
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import ComplementNB, BernoulliNB, MultinomialNB

# %%
# the models that you want to compare
stat_models = {
    'clf_randforest' : RandomForestClassifier(),
    'clf_knn' : KNeighborsClassifier(),
    'clf_dt' : DecisionTreeClassifier(),

}

# the optimisation parameters for each of the above models
params = {
    'clf_randforest': {
        'n_jobs': [-1],
        
        'criterion': ['gini', 'entropy']
    },
    'clf_knn': {
        'weights': ['distance'],
        'algorithm': ['ball_tree', 'kd_tree',]
         },
    
    'clf_dt' : {
        'criterion': ['gini', 'entropy'],
        'min_samples_split': [2, 5, 10],
        'random_state':[42]
         },
                     }

# %%
def fit_search(X_data, y_data):
        """
        fits the list of models to the training data, thereby obtaining in each 
        case an evaluation score after GridSearchCV cross-validation
        """
        for name in stat_models.keys():
            est = stat_models[name]
            est_params = params[name]
            gscv = GridSearchCV(estimator=est, param_grid=est_params, cv=10)
            gscv.fit(X_data, y_data)
            print("best parameters are: {}".format(gscv.best_estimator_))
            y_pred = gscv.predict(X_data)
            print(classification_report(y_data, y_pred))

# %%
# assess class distribution for prior / weights
counter = Counter(y3_train)
print(counter)
print(len(y3_train))
prob1= 2279/3392
prob0=434/3392
print (prob1)
print (prob0)
# Out:
# Counter({1: 2051, 0: 390})
# 2441
# 0.671875
# 0.12794811320754718

# %% [markdown]
# import warnings
# warnings.filterwarnings('ignore')
#
# #grid search on smote balanced data
# fit_search(X_train, y_train)

# %%
# grid search on unaltered data/unbalanced
fit_search(X3_train, y3_train)
warnings.filterwarnings('ignore')
# Out:
# best parameters are: RandomForestClassifier(n_jobs=-1)
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       390
#            1       1.00      1.00      1.00      2051
#
#     accuracy                           1.00      2441
#    macro avg       1.00      0.99      0.99      2441
# weighted avg       1.00      1.00      1.00      2441
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# /Users/badmin/opt/anaconda3/lib/python3.7/site-packages/sklearn/neighbors/_base.py:415: UserWarning: cannot use tree with sparse input: using brute force
#   warnings.warn("cannot use tree with sparse input: "
# best parameters are: KNeighborsClassifier(algorithm='ball_tree', weights='distance')
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       390
#            1       1.00      1.00      1.00      2051
#
#     accuracy                           1.00      2441
#    macro avg       0.99      1.00      1.00      2441
# weighted avg       1.00      1.00      1.00      2441
#
# best parameters are: DecisionTreeClassifier(random_state=42)
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       390
#            1       1.00      1.00      1.00      2051
#
#     accuracy                           1.00      2441
#    macro avg       0.99      1.00      1.00      2441
# weighted avg       1.00      1.00      1.00      2441

# %%
print('Test label shape:', np.shape(y3_test))
print('Train label shape:', np.shape(y3_train))
print('Test shape:', np.shape(X3_test))
print('Train shape:', np.shape(X3_train))
# Out:
# Test label shape: (679,)
# Train label shape: (2441,)
# Test shape: (679, 16802)
# Train shape: (2441, 16802)

# %%
from sklearn.model_selection import cross_val_score, KFold
# x=X_train_scaled, y = y_train_scaled, z = y_test_scaled
def cv_score(model, x_train, y_train, y_test, y_pred):
    #CV scores, 10 fold CV
    scores = cross_val_score(model, x_train, y_train, cv=10)
    #Prediction and accuracy
    accuracy_test = accuracy_score(y_test, y_pred)
    #Print the summary
    print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
    print ("Test Accuracy: %0.2f" % (accuracy_test))

# %%
#visualize confusion matrix
def vis_cm(model, X, y, y_pred):
    score = model.score(X, y)
    confusion = confusion_matrix(y, y_pred)
    
    group_names = ['True Neg','False Pos','False Neg','True Pos']
    group_counts = ['{0:0.0f}'.format(value) for value in
                    confusion.flatten()]
    group_percentages = ['{0:.2%}'.format(value) for value in
                     confusion.flatten()/np.sum(confusion)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(confusion, annot=labels, fmt='', cmap='Blues')
    matrix_title = "Test Accuracy: %0.2f for {model}" % (score)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
# Instantiate multinomial bayes
mnb = MultinomialNB(alpha=1.0, fit_prior=True)

# Fit the model to training data
mnb_model = mnb.fit(X3_train, y3_train)

# Predict on test set
y_pred_mnb = mnb_model.predict(X3_test)
print(mnb_model.score(X3_train, y3_train))
print(mnb_model.score(X3_test, y3_test))
print(classification_report(y_test, y_pred_mnb))
# Out:
# 0.869315854158132
# 0.845360824742268
#               precision    recall  f1-score   support
#
#            0       0.83      0.05      0.09       109
#            1       0.85      1.00      0.92       570
#
#     accuracy                           0.85       679
#    macro avg       0.84      0.52      0.50       679
# weighted avg       0.84      0.85      0.78       679

# %%
#did not perform well on negative sentiment data(also smaller class)

# %%
# get accuracy scores for training data vs test data
cv_score(mnb_model, X3_train, y3_train, y3_test, y_pred_mnb)
# Out:
# Accuracy: 0.85 (+/- 0.01)
# Test Accuracy: 0.85

# %%
confusion_matrix(y3_test, y_pred_mnb)
# Out:
# array([[  5, 104],
#        [  1, 569]])

# %%
#plot roc/auc
test_probs = mnb_model.predict_proba(X3_test)
preds  = test_probs[:,1]
train_probs = mnb_model.predict_proba(X3_train)
y_train_score  = train_probs[:,1]


train_fpr, train_tpr, train_thresholds = roc_curve(y3_train, y_train_score)
test_fpr, test_tpr, test_thresholds = roc_curve(y3_test, preds)

dt_fpr, dt_tpr, dt_th = roc_curve(y3_test, preds)

print('Train AUC: {}'.format(auc(train_fpr, train_tpr)))
print('Test AUC: {}'.format(auc(test_fpr, test_tpr)))

plt.figure(figsize=(10, 8))
lw = 2

plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Train ROC curve')
plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Test ROC curve')

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train AUC: 0.9738589055995199
# Test AUC: 0.7656365684854338

# %%
# Instantiate bernoulli naive bayes on og data
bnb = BernoulliNB(alpha=1.0, fit_prior=True)

# Fit the model to training data
bnb_model = bnb.fit(X3_train, y3_train)

# Predict on test set
y_pred_bnb = bnb_model.predict(X3_test)
print(bnb_model.score(X3_train, y3_train))
print(bnb_model.score(X3_test, y3_test))
print(classification_report(y_test, y_pred_bnb))
# Out:
# 0.8811962310528472
# 0.845360824742268
#               precision    recall  f1-score   support
#
#            0       0.83      0.05      0.09       109
#            1       0.85      1.00      0.92       570
#
#     accuracy                           0.85       679
#    macro avg       0.84      0.52      0.50       679
# weighted avg       0.84      0.85      0.78       679

# %%
# cv scores
cv_score(bnb_model, X3_train, y3_train, y3_test, y_pred_bnb)
# Out:
# Accuracy: 0.84 (+/- 0.01)
# Test Accuracy: 0.85

# %%
confusion_matrix(y3_test, y_pred_bnb)
# Out:
# array([[  5, 104],
#        [  1, 569]])

# %%
test_probs = bnb_model.predict_proba(X3_test)
preds  = test_probs[:,1]
train_probs = bnb_model.predict_proba(X3_train)
y_train_score  = train_probs[:,1]


train_fpr, train_tpr, train_thresholds = roc_curve(y3_train, y_train_score)
test_fpr, test_tpr, test_thresholds = roc_curve(y3_test, preds)

dt_fpr, dt_tpr, dt_th = roc_curve(y3_test, preds)

print('Train AUC: {}'.format(auc(train_fpr, train_tpr)))
print('Test AUC: {}'.format(auc(test_fpr, test_tpr)))

plt.figure(figsize=(10, 8))
lw = 2

plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Train ROC curve')
plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Test ROC curve')

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train AUC: 0.9608502419082623
# Test AUC: 0.684588765491711

# %%
#neither of the bayes classifiers performed well on the negative sentiment data

# %%
# Instantiate random forest on balanced smote data
rf = RandomForestClassifier(n_jobs=-1)

# Fit the model to training data
rf_model = rf.fit(X3_train, y3_train)

# Predict on test set
y_pred_rf = rf_model.predict(X3_test)
print(rf_model.score(X3_train, y3_train))
print(rf_model.score(X3_test, y3_test))
print(classification_report(y3_test, y_pred_rf))
# Out:
# 0.9975419909873003
# 0.8703976435935199
#               precision    recall  f1-score   support
#
#            0       0.89      0.22      0.35       109
#            1       0.87      0.99      0.93       570
#
#     accuracy                           0.87       679
#    macro avg       0.88      0.61      0.64       679
# weighted avg       0.87      0.87      0.84       679

# %%
 #cv scores
cv_score(rf_model, X3_train, y3_train, y3_test, y_pred_rf)
# Out:
# Accuracy: 0.87 (+/- 0.02)
# Test Accuracy: 0.87

# %%
confusion_matrix(y_test, y_pred_rf)
# Out:
# array([[ 24,  85],
#        [  3, 567]])

# %%
test_probs = rf_model.predict_proba(X3_test)
preds  = test_probs[:,1]
train_probs = rf_model.predict_proba(X3_train)
y_train_score  = train_probs[:,1]


train_fpr, train_tpr, train_thresholds = roc_curve(y3_train, y_train_score)
test_fpr, test_tpr, test_thresholds = roc_curve(y3_test, preds)

dt_fpr, dt_tpr, dt_th = roc_curve(y3_test, preds)

print('Train AUC: {}'.format(auc(train_fpr, train_tpr)))
print('Test AUC: {}'.format(auc(test_fpr, test_tpr)))

plt.figure(figsize=(10, 8))
lw = 2

plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Train ROC curve')
plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Test ROC curve')

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train AUC: 0.9999774969058245
# Test AUC: 0.8021648157089973

# %%
# did not perform well on negative data either

# %%
knn_clf = KNeighborsClassifier(algorithm='ball_tree', weights='distance')
# Fit the model to training data
knn_model = knn_clf.fit(X3_train, y3_train)
# Predict on test set
y_pred_knn = knn_model.predict(X3_test)
print(knn_model.score(X3_train, y3_train))
print(knn_model.score(X3_test, y3_test))
print(classification_report(y3_test, y_pred_knn))
# confusion matrix
confusion_matrix(y3_test, y_pred_knn)
# Out:
# 0.9975419909873003
# 0.8600883652430045
#               precision    recall  f1-score   support
#
#            0       0.64      0.29      0.40       109
#            1       0.88      0.97      0.92       570
#
#     accuracy                           0.86       679
#    macro avg       0.76      0.63      0.66       679
# weighted avg       0.84      0.86      0.84       679
# array([[ 32,  77],
#        [ 18, 552]])

# %%
# cv scores
cv_score(knn_model, X3_train, y3_train, y3_test, y_pred_knn)
# Out:
# Accuracy: 0.87 (+/- 0.03)
# Test Accuracy: 0.86

# %%
test_probs = knn_model.predict_proba(X3_test)
preds  = test_probs[:,1]
train_probs = knn_model.predict_proba(X3_train)
y_train_score  = train_probs[:,1]


train_fpr, train_tpr, train_thresholds = roc_curve(y3_train, y_train_score)
test_fpr, test_tpr, test_thresholds = roc_curve(y3_test, preds)

dt_fpr, dt_tpr, dt_th = roc_curve(y3_test, preds)

print('Train AUC: {}'.format(auc(train_fpr, train_tpr)))
print('Test AUC: {}'.format(auc(test_fpr, test_tpr)))

plt.figure(figsize=(10, 8))
lw = 2

plt.plot(train_fpr, train_tpr, color='blue',
         lw=lw, label='Train ROC curve')
plt.plot(test_fpr, test_tpr, color='darkorange',
         lw=lw, label='Test ROC curve')

plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.yticks([i/20.0 for i in range(21)])
plt.xticks([i/20.0 for i in range(21)])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Train AUC: 0.9999774969058246
# Test AUC: 0.7070416867857718

# %%
dt_clf = DecisionTreeClassifier(random_state=42)
# Fit the model to training data
dt_model = dt_clf.fit(X3_train, y3_train)
# Predict on test set
y_pred_dt = dt_model.predict(X3_test)
print(dt_model.score(X3_train, y3_train))
print(dt_model.score(X3_test, y3_test))
print(classification_report(y3_test, y_pred_dt))
confusion_matrix(y3_test, y_pred_dt)
# Out:
# 0.9975419909873003
# 0.8409425625920471
#               precision    recall  f1-score   support
#
#            0       0.51      0.42      0.46       109
#            1       0.89      0.92      0.91       570
#
#     accuracy                           0.84       679
#    macro avg       0.70      0.67      0.68       679
# weighted avg       0.83      0.84      0.84       679
# array([[ 46,  63],
#        [ 45, 525]])

# %%
# cv scores
cv_score(dt_model, X_train, y_train, y_test, y_pred_dt)
# Out:
# Accuracy: 0.92 (+/- 0.10)
# Test Accuracy: 0.84

# %% [markdown]
# none of the statistical methods performed well on data, due to lack of data. this was tried on smote dataset as well, with similar results

# %% [markdown]
# # word2vec

# %%
from tqdm import tqdm

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
from gensim.models import Word2Vec 
import time

start_time = time.time()

# %%
lb = LabelBinarizer()
y = pd.DataFrame()
y = lb.fit_transform(df['target'])

# %%
X= df['wordl'].copy()

# %%
train_corpus = df['wordl'].copy()
size=100
## create list of lists of unigrams
corpus = []
for string in train_corpus:
   words = string.split()
   grams = [" ".join(words[i:i+1]) 
               for i in range(0, len(words), 1)]
   corpus.append(grams)

## detect bigrams 
bigrams_detector = gensim.models.phrases.Phrases(corpus, 
                delimiter=" ".encode(), min_count=5, threshold=7)
bigrams_detector = gensim.models.phrases.Phraser(bigrams_detector)

# %%
wv_nlp_model_file = 'nlp_' + 'word2vec_' + str(size) + '.model'
wv_nlp_model = Word2Vec(corpus,  min_count=3,
                     window=5,
                     size=100,
                     sg=1,
                     alpha=0.01, 
                     min_alpha=0.0007, 
                     workers=5)
print("Time taken to train word2vec nlp model: " + str(time.time() - start_time))
wv_nlp_model.save(wv_nlp_model_file)
# Out:
# Time taken to train word2vec nlp model: 1.3953678607940674

# %%
## tokenize text
tokenizer = Tokenizer(split=' ', 
                      )
tokenizer.fit_on_texts(corpus)
dic_vocabulary = tokenizer.word_index
## create sequence
text2seq= tokenizer.texts_to_sequences(corpus)
## padding sequence
X = pad_sequences(text2seq, 
                    maxlen=maxlen+1, padding="post", truncating="post")

# %%
vocab_size = (len(dic_vocabulary)+1)
vocab_size
# Out:
# 5059

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                     df['target'], 
                                                     random_state=42,
                                                     test_size=.2, stratify=y)

# %%
sns.heatmap(X_train==0, vmin=0, vmax=1, cbar=False)
plt.show()

# %%
## start the matrix (length of vocabulary x vector size) with all 0s
embeddings = np.zeros((len(dic_vocabulary)+1, size))
for word,idx in dic_vocabulary.items():
    ## update the row with vector
    try:
        embeddings[idx] =  wv_nlp_model[word]
    ## if word not in model then skip and the row stays all 0s
    except:
        pass

# %%
i = 0

## list of text: ["I like this", ...]
len_txt = len(df["wordl"].iloc[i].split())
print("from: ", df["wordl"].iloc[i], "| len:", len_txt)

## sequence of token ids: [[1, 2, 3], ...]
len_tokens = len(X_train[i])
print("to: ", X_train[i], "| len:", len(X_train[i]))

## vocabulary: {"I":1, "like":2, "this":3, ...}
print("check: ", df["wordl"].iloc[i].split()[0], 
      " -- idx in vocabulary -->", 
      dic_vocabulary[df["wordl"].iloc[i].split()[0]])

print("vocabulary: ", dict(list(dic_vocabulary.items())[0:5]), "... (padding element, 0)")
# Out:
# from:  hr tweeting rise dead need upgrade plugin station | len: 8
# to:  [ 137   52  170   20  198  253   42   39   12  114   15 2438    0    0
#     0    0    0    0] | len: 18
# check:  hr  -- idx in vocabulary --> 1028
# vocabulary:  {'store': 1, 'app': 2, 'not': 3, 'new': 4, 'pop': 5} ... (padding element, 0)

# %%
# plot heatmap for test data
sns.heatmap(X_test==0, vmin=0, vmax=1, cbar=False)
plt.show()

# %%
word = "app"
print("dic[word]:", dic_vocabulary[word], "|idx")
print("embeddings[idx]:", embeddings[dic_vocabulary[word]].shape, 
      "|vector")
print(embeddings.shape)
print(len(dic_vocabulary))
# Out:
# dic[word]: 2 |idx
# embeddings[idx]: (100,) |vector
# (5059, 100)
# 5058

# %%
print('Test label shape:', np.shape(y_test))
print('Train label shape:', np.shape(y_train))
print('Test shape:', np.shape(X_test))
print('Train shape:', np.shape(X_train))
# Out:
# Test label shape: (679,)
# Train label shape: (2713,)
# Test shape: (679, 18)
# Train shape: (2713, 18)

# %%
regularizerA = keras.regularizers.l2(0.01)
regularizerB = keras.regularizers.l2(0.001)

# %%
modelw = models.Sequential()

## embedding
modelw.add(layers.Embedding(vocab_size, 500, input_length=maxlen+1, ))
#modelw.add(layers.Dropout(0.5))                          
#modelw.add(layers.BatchNormalization(momentum=0.8))
## final dense layers
modelw.add(layers.Dense(300, activation='relu', kernel_initializer=initializer ))
#modelw.add(layers.BatchNormalization(momentum=0.9))
#modelw.add(layers.Dropout(0.4))     
modelw.add(layers.Dense(100, activation='relu', ))  
#modelw.add(layers.BatchNormalization(momentum=0.6))
modelw.add(layers.Dense(44, activation='relu',  )) 
modelw.add(layers.GlobalAveragePooling1D()),
modelw.add(layers.Dense(1, activation='sigmoid'))
a_opt = optimizers.Adam(lr=1e-6,)

## compile
modelw.compile(loss='binary_crossentropy',
              optimizer=a_opt, metrics=['accuracy'])

modelw.summary()
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_19 (Embedding)     (None, 18, 500)           2529500
# _________________________________________________________________
# dense_78 (Dense)             (None, 18, 300)           150300
# _________________________________________________________________
# dense_79 (Dense)             (None, 18, 100)           30100
# _________________________________________________________________
# dense_80 (Dense)             (None, 18, 44)            4444
# _________________________________________________________________
# global_average_pooling1d_18  (None, 44)                0
# _________________________________________________________________
# dense_81 (Dense)             (None, 1)                 45
# =================================================================
# Total params: 2,714,389
# Trainable params: 2,714,389
# Non-trainable params: 0
# _________________________________________________________________

# %%
# early stopping to prevent overfitting
es_callback = keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=10)
#es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience
# Epoch 61/1000
# 2441/2441 [==============================] - 1s 443us/step - loss: 0.6529 - accuracy: 0.8394 - val_loss: 0.6514 - val_accuracy: 0.8456
# Epoch 62/1000
# 2441/2441 [==============================] - 1s 447us/step - loss: 0.6523 - accuracy: 0.8394 - val_loss: 0.6509 - val_accuracy: 0.8456
# Epoch 63/1000
# 2441/2441 [==============================] - 1s 477us/step - loss: 0.6518 - accuracy: 0.8394 - val_loss: 0.6503 - val_accuracy: 0.8456
# Epoch 64/1000
# 2441/2441 [==============================] - 1s 457us/step - loss: 0.6512 - accuracy: 0.8394 - val_loss: 0.6497 - val_accuracy: 0.8456
# Epoch 65/1000
# 2441/2441 [==============================] - 1s 467us/step - loss: 0.6506 - accuracy: 0.8394 - val_loss: 0.6491 - val_accuracy: 0.8456
# Epoch 66/1000
# 2441/2441 [==============================] - 1s 460us/step - loss: 0.6500 - accuracy: 0.8394 - val_loss: 0.6485 - val_accuracy: 0.8456
# Epoch 67/1000
# 2441/2441 [==============================] - 1s 458us/step - loss: 0.6494 - accuracy: 0.8394 - val_loss: 0.6479 - val_accuracy: 0.8456
# Epoch 68/1000
# 2441/2441 [==============================] - 1s 455us/step - loss: 0.6488 - accuracy: 0.8394 - val_loss: 0.6472 - val_accuracy: 0.8456
# Epoch 69/1000
# 1440/2441 [================>.............] - ETA: 0s - loss: 0.6485 - accuracy: 0.8382

# %%
modelw_dict = training.history
modelw_dict.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plot_history(training)
acc_loss_plot(modelw_dict)

# %%
## encode y
dic_y_mapping = {n:label for n,label in 
                 enumerate(np.unique(y_train))}
inverse_dic = {v:k for k,v in dic_y_mapping.items()}
y_train = np.array([inverse_dic[y] for y in y_train])


metrics = [k for k in training.history.keys() if ("loss" not in k) and ("val" not in k)]
fig, ax = plt.subplots(nrows=1, ncols=2, sharey=True)
ax[0].set(title="Training")
ax11 = ax[0].twinx()
ax[0].plot(training.history['loss'], color='black')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss', color='black')
for metric in metrics:

    ax11.plot(training.history[metric], label=metric)
ax11.set_ylabel("Score", color='steelblue')
ax11.legend()
ax[1].set(title="Validation")
ax22 = ax[1].twinx()
ax[1].plot(training.history['val_loss'], color='black')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss', color='black')
for metric in metrics:
     ax22.plot(training.history['val_'+metric], label=metric)
ax22.set_ylabel("Score", color="steelblue")
plt.show()

# %%
results_train = modelw.evaluate(X_train, y_train)
print('Training:', results_train)

results_test = modelw.evaluate(X_test, y_test)
print('Test:', results_test)
# Out:
# 2713/2713 [==============================] - 0s 82us/step
# Training: [0.42834733229390026, 0.8400294780731201]
# 679/679 [==============================] - 0s 76us/step
# Test: [0.430939149786341, 0.8394697904586792]

# %%
# predict probabilities for test set
yhat_probs = modelw.predict(X_test, verbose=0)
# predict crisp classes for test set
yhat_classes = modelw.predict_classes(X_test, verbose=0)

# reduce to 1d array
yhat_probs = yhat_probs[:, 0]
yhat_classes = yhat_classes[:, 0]
get_metrics(y_test, yhat_classes,yhat_probs)
# Out:
# Accuracy: 0.839470
# Precision: 0.839470
# Recall: 1.000000
# F1 score: 0.912730
# ROC AUC: 0.617632
# [[  0 109]
#  [  0 570]]

# %%
vocab = list(wv_nlp_model .wv.vocab)
Xwv = wv_nlp_model [wv_nlp_model.wv.vocab]
df_wv =pd.DataFrame(Xwv)

print(len(df_wv))

df_wv.head()
# Out:
# 1697
#          0         1         2         3         4         5         6   \
# 0 -0.009103 -0.001491  0.002387 -0.007076 -0.004715  0.001389  0.000948
# 1 -0.032717  0.010661  0.002479 -0.022044 -0.022875 -0.008541  0.017987
# 2 -0.016924  0.002864  0.001190 -0.017788 -0.011308 -0.010126  0.009264
# 3 -0.016978  0.002383 -0.003438 -0.012327 -0.012541 -0.004339  0.003870
# 4 -0.122144  0.031184  0.008812 -0.083434 -0.079820 -0.052778  0.085763
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.000351 -0.007090  0.001742  ... -0.009937  0.002056 -0.000303  0.010438
# 1 -0.018131 -0.028396 -0.007278  ... -0.016752  0.004424 -0.010579  0.034922
# 2 -0.013069 -0.016699 -0.001198  ... -0.013641  0.001768 -0.006760  0.019798
# 3 -0.009801 -0.014374 -0.007410  ... -0.009011  0.005889 -0.000215  0.013271
# 4 -0.065237 -0.108293 -0.026352  ... -0.081460  0.011393 -0.048687  0.145727
#
#          94        95        96        97        98        99
# 0  0.002177  0.000202 -0.002464  0.010206  0.006777 -0.003675
# 1  0.008768 -0.011920 -0.015827  0.029867  0.008174 -0.011368
# 2  0.000907 -0.004761 -0.007558  0.017727  0.004508 -0.011069
# 3  0.000737 -0.005494 -0.000364  0.009395  0.001842 -0.001323
# 4  0.022619 -0.032572 -0.044451  0.113951  0.046188 -0.044473
#
# [5 rows x 100 columns]

# %%
from sklearn.decomposition import IncrementalPCA    
from sklearn.manifold import TSNE                    
import plotly


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    for word in model.wv.vocab:
        vectors.append(model.wv[word])
        labels.append(word)

    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    vectors = np.asarray(vectors)
    tsne = TSNE(n_components=num_dimensions, random_state=42)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels

def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True, ):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels,)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')

# %%
x_vals, y_vals, labels = reduce_dimensions(wv_nlp_model)
plot_with_plotly(x_vals, y_vals, labels)

# %% [markdown]
# # Final Model

# %%
def model():
    model = models.Sequential([
        layers.Dense(64, input_dim=X_train.shape[1], activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    return model

es_callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)
# best model callback 
bm_callback = keras.callbacks.ModelCheckpoint("model.h5",
                                             save_best_only=True)
callbacks = [es_callback, bm_callback]
pipe = pipeline.Pipeline([
    ('rescale', preprocessing.StandardScaler()),
    ('nn', KerasClassifier(build_fn=model, nb_epoch=10, batch_sizerandom=128,
                           validation_split=0.2, callbacks=[early_stopping]))
])


pipe.fit(X_train.values, y_train.values)

# %% [markdown]
# # Conclusion

# %% [markdown]
# models are all overfitting in some capacity. attempted making neural network smaller, applied bias, kernel initializers, l1 and l2 regularizers, batch normalization layers, and dropout layers to minimize loss providing slightly better results but still overfitting occurs to provide accuracy over 80%. this is due to unbalanced and small dataset. this occurs on smote balanced data as well as data ran with weights provided. More data should be obtained to improve results. further assessment planned on retweets and hashtags relativity to sentiment
